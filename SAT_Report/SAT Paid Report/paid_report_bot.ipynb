# %%
import os
import json
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from datetime import datetime

# %%
# Load .env environment variables
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
def initialize_llm():
    provider = os.getenv("MODEL_PROVIDER")
    if provider == "GROQ":
        print(1)
        # Initialize the Groq LLM
        llm = ChatGroq(
            model= os.getenv("GROQ_MODEL"),
            api_key=os.getenv("GROQ_API_KEY"),
            temperature=0.1,
            max_tokens=5000,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
        )
    elif provider == "OPENAI":
        # Initialize the OpenAI LLM
        llm = ChatOpenAI(
            model= os.getenv("OPENAI_MODEL"),
            openai_api_key=os.getenv("OPENAI_API_KEY"),
            temperature=0.1,
            max_tokens=5000,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
        )
    return llm

# %%
llm = initialize_llm()

# %%
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x00000176901DAFC0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000176902738C0> root_client=<openai.OpenAI object at 0x000001768FC7F860> root_async_client=<openai.AsyncOpenAI object at 0x000001769032CF20> model_name='gpt-4.1-mini' temperature=0.1 model_kwargs={} openai_api_key=SecretStr('**********') presence_penalty=0.0 frequency_penalty=0.0 top_p=0.95 max_tokens=5000

# %%
Executive_Summary_PROMPT = """ 
Student Data: 
Name: {student_name} 
Persona Name: {persona_name} 
Persona strengths: {persona_strengths} 
Persona challenges: {persona_challenges} 
 
SAT Performance: 
Total Score: {current_sat_score_total}  
Accuracy: {current_sat_accuracy} 
Time Management: {current_sat_time_management} 
 
Top 3 Strengths in Math with accuracy: 
{math_top_3} 
 
Top 3 Weaknesses in Math with accuracy: 
{math_bottom_3} 
 
Top 3 Strengths in Reading & Writing with accuracy: 
{rw_top_3} 
 
Top 3 Weaknesses in Reading & Writing with accuracy: 
{rw_bottom_3} 
 
Target SAT Dates: {planned_sat_date} 
Realistic Target Score: {goal_score} 
 
Instructions: 
You are an expert SAT coach and behavioral science specialist. Write a personalized comprehensive SAT readiness report for a Sherpal student using the structured input provided.
Your tone should be **authentic, calm, and professional** — never salesy or exaggerated and matching to **students persona** But not frequently mentioning **students persona** name. Speak to a smart, serious student. The report includes multiple sections and should remain motivational yet concise throughout. Avoid lengthy explanations—prioritize clear, high-impact takeaways over broad commentary - keep it inspiring, focused, and straight to the point. Maintain consistent tone and phrasing across sections to support reliable and repeatable output.
 

Requirements for each section:

**CRITICAL: Return ONLY valid JSON in exactly this structure:** 
Do not wrap the JSON response inside markdown code block tags like ```json or ``` — return only raw JSON :

{{

    "Executive Summary": "Write a brief summary introduction with the student's name and persona name in one short sentence by summarizing their strengths and challenges into 1-2 key words each (e.g., "{persona_name} is a [strength keyword] yet [challenge keyword] learner"). Mention their current SAT score, accuracy, and time management (150 words max).",

    "Key Strengths": 
    {{
        "Reading & Writing: these are the top 3 Reading and writing skills: {rw_top_3}
        output must follow the below structure as array of strings:
        ["<skill1> (<accuracy>%)", "<skill2> (<accuracy>%)", "<skill3> (<accuracy>%)"],

        "Math: these are the top 3 Math skills: {math_top_3}
        output must follow the below structure as array of strings:
        ["<skill1> (<accuracy>%)", "<skill2> (<accuracy>%)", "<skill3> (<accuracy>%)"]

    }},

    "Focus Areas for Growth": {{
        "Reading & Writing: these are the bottom three Reading and Writing skills:{rw_bottom_3}
        output must follow the below structure as array of strings:"
        "["<skill1> (<accuracy>%)", "<skill2> (<accuracy>%)", "<skill3> (<accuracy>%)"]",
        "Math: these are the bottom three Math skills:{math_bottom_3} 
        output must follow the below structure as array of strings:"
        "["<skill1> (<accuracy>%)", "<skill2> (<accuracy>%)", "<skill3> (<accuracy>%)"]"

    }},

    "Bottom 3 Skills Resources:": {{
        "Reading & Writing": these are the bottom 3 skills with resources:{rw_bottom_three_resources}
        output must follow the below structure as array of strings:" 
        [
            "• <skill name> - <link>",
            "• <skill name> - <link>",
            "• <skill name> - <link>"
        ],
        "Math": {math_bottom_three_resources}
        [
            "• <skill name> - <link>",
            "• <skill name> - <link>",
            "• <skill name> - <link>"
        ]
    }}
  }}
"""

# %%
FOUNDTION_PHASE_PROMPT = """
You are an expert SAT coach and behavioral science specialist. Write a personalized SAT Foundation Phase study plan, using the structured input provided.
Your tone should be **authentic, calm, and professional** — never salesy or exaggerated and matching to **students persona** But not frequently mentioning **students persona** name. Speak to a smart, serious student. The report includes multiple sections and should remain motivational yet concise throughout.

Create a personalized SAT Foundation Phase study plan for a student named {student_name}. This student is described as a "{persona_name}", with the following strengths: {persona_strengths}, faces these challenges: {persona_challenges}, and growth strategies: {growth_strategies}.

Here is the student's profile and data:
- Name: {student_name}
- Persona Name: {persona_name}
- Key Strengths: {persona_strengths}
- Areas of Improvement: {persona_challenges}
- Growth Strategies: {growth_strategies}

- Current SAT Score: {current_sat_score_total}
- Goal SAT Score: {goal_score}

- Reading & Writing Skill Accuracies (in priority order): {foundation_skills_rw}
- Math Skill Accuracies (in priority order): {foundation_skills_math}


Avoid lengthy explanations—prioritize clear, high-impact takeaways over broad commentary - keep it inspiring, focused, and straight to the point. Maintain consistent tone and phrasing across sections to support reliable and repeatable output.

The Foundation Phase will take place from {foundation_date_range}.

Instructions:
- Do not include '\\n'
- Data should be purely generated based on the Persona details.
- avoid bullet points, lists, or line breaks between sentences.

Purpose:
To build a strong baseline of understanding across all SAT-tested skills with focus on accuracy, concept clarity, and learning discipline.

Key Focus:
- Establish structured study habits
- Improve accuracy and comprehension of core skills
- Identify and start closing skill gaps
- Build confidence slowly through consistency

Using the above data, generate a **Foundation Phase** study report divided into the following sections with these exact headings:

1. Weekly Goals  
2. Practice Methods  
3. Weekly Structure  
4. Flex Day Activities

Requirements for each section:

**CRITICAL: Return ONLY valid JSON in exactly this structure:**
Do not wrap the JSON response inside markdown code block tags like ```json or ``` — return only raw JSON :

{{
    title: "Foundation Phase",
    description:
    [
      {{
         "title": "Weekly Goals",
         "description": "Summarize clear, specific, outcome-driven goals the student should achieve each week during the Foundation Phase. Avoid mentioning how to achieve them or practice methods. Focus on measurable improvements in both Math and Reading & Writing, steady reduction of repeat mistakes, and improved reasoning and accuracy."
      }},
      {{
         "title": "Skill Areas",
         "description":
         [
            {{
               "title": "Math", 
               "description": "List these math skills: {foundation_skills_math}"
            }},
            {{
               "title": "Reading & Writing",
               "description": "List these reading and writing skills: {foundation_skills_rw}"
            }},
         ]
      }},
      {{
         "title": "Practice Methods",
         "description": "For each subject (Reading & Writing and Math), provide detailed, skill-specific practice methods. Use bullet points (starting with '-') for each skill. Mention the skill name in bold or caps, then describe exactly how the student should practice that skill—aligned with their strengths, challenges, and growth strategies. Ensure routines are structured (daily/weekly) and match the learning style of a disciplined student who thrives on consistency while developing adaptability.

         Guidelines:
         - The practice methods should align with these growth strategies: {growth_strategies}
         - The practice method of each skill should align with these skill - summary: {skill_summary_foundation}
         - One sentence from the level method should be included for each skill from this: {skill_level_message_foundation}

         output should be in this format:
         {{
            "title": "Math",
            "description": [
               "<skill>": "practice method for the skill with level_message",
               "<skill>": "practice method for the skill with level_message",
            ],
            "title": "Reading and Writing",
            "description": [
               "<skill>": "practice method for the skill with level_message",
               "<skill>": "practice method for the skill with level_message",
            ],
         }}"
      }},
      {{
         "title": "Weekly Structure",
         "description": "Provide a generic overview of the weekly routine. Explain how each weekday will include focused dual-skill practice (one Math and one Reading & Writing skill), starting with the weakest skills early in the week, midweek focus on moderate skills, Fridays for review, Saturdays for timed full-length practice with review, and one Flex Day for rest and adaptability."
      }},
      {{
         "title": "Flex Day Activities", 
         "description": "Suggest actionable, persona-aligned activities that support rest, reflection, cognitive flexibility, and low-pressure practice. Include reflection on errors, experimenting with new tools or techniques, mixed-skill challenges, physical or mindfulness rest activities, and goal-setting for the next week."
      }}
    ]
}}

**Requirements:**
- Return valid JSON only - no additional text
- Keep descriptions concise but personalized 
- Do not include any generic or vague advice. Use the data provided to personalize every recommendation.
- Make Flex Day Activities unique to the student's persona
"""

# %%
ELEVATION_PHASE_PROMPT = """
You are an expert SAT coach and behavioral science specialist. Write a personalized SAT Elevation Phase study plan, using the structured input provided.
Your tone should be **authentic, calm, and professional** — never salesy or exaggerated and matching to **students persona** But not frequently mentioning **students persona** name. Speak to a smart, serious student. The report includes multiple sections and should remain motivational yet concise throughout.

Create a personalized SAT Elevation Phase study plan for a student named {student_name}. This student is described as a "{persona_name}", with the following strengths: {persona_strengths}, faces these challenges: {persona_challenges}, and growth strategies: {growth_strategies}.

Here is the student's profile and data:
- Name: {student_name}
- Persona Name: {persona_name}
- Key Strengths: {persona_strengths}
- Areas of Improvement: {persona_challenges}
- Growth Strategies: {growth_strategies}

- Current SAT Score: {current_sat_score_total}
- Goal SAT Score: {goal_score}

- Reading & Writing Skill Accuracies (in priority order): {elevation_skills_rw}
- Math Skill Accuracies (in priority order): {elevation_skills_math}


Avoid lengthy explanations—prioritize clear, high-impact takeaways over broad commentary - keep it inspiring, focused, and straight to the point. Maintain consistent tone and phrasing across sections to support reliable and repeatable output.

The Elevation Phase will take place from {elevation_date_range}.

Instructions:
- Do not include '\\n'
- Data should be purely generated based on the Persona details.
- avoid bullet points, lists, or line breaks between sentences.

Purpose:
To push skill application under timed conditions, refine accuracy, and improve cognitive flexibility with mid-level and advanced skills.

Key Focus:
- Reduce careless mistakes
- Reinforce second-tier skills (those partially mastered)
- Introduce moderate time pressure
- Layer more strategic practice
- Use performance review cycles (analyze → adapt → retest)

Using the above data, generate a **Elevation Phase** study report divided into the following sections with these exact headings:

1. Weekly Goals  
2. Practice Methods  
3. Weekly Structure  
4. Flex Day Activities

Requirements for each section:

**CRITICAL: Return ONLY valid JSON in exactly this structure:**
Do not wrap the JSON response inside markdown code block tags like ```json or ``` — return only raw JSON :

{{
    title: "Elevation Phase",
    description:
    [
      {{
         "title": "Weekly Goals",
         "description": "Summarize clear, specific, outcome-driven goals the student should achieve each week during the Elevation Phase. Avoid mentioning how to achieve them or practice methods. Focus on measurable improvements in both Math and Reading & Writing, steady reduction of repeat mistakes, and improved reasoning and accuracy."
      }},
      {{
         "title": "Skill Areas",
         "description":
         [
            {{
               "title": "Math", 
               "description": "List these math skills: {elevation_skills_math}"
            }},
            {{
               "title": "Reading & Writing",
               "description": "List these reading and writing skills: {elevation_skills_rw}"
            }},
         ]
      }},
      {{
         "title": "Practice Methods",
         "description": "For each subject (Reading & Writing and Math), provide detailed, skill-specific practice methods. Use bullet points (starting with '-') for each skill. Mention the skill name in bold or caps, then describe exactly how the student should practice that skill—aligned with their strengths, challenges, and growth strategies. Ensure routines are structured (daily/weekly) and match the learning style of a disciplined student who thrives on consistency while developing adaptability. The practice methods should align with these growth strategies: {growth_strategies}:
         
         Guidelines:
         - The practice methods should align with these growth strategies: {growth_strategies}
         - The practice method of each skill should align with these skill - summary: {skill_summary_foundation}
         - One sentence from the level method should be included for each skill from this: {skill_level_message_foundation}

         output should be in this format:
         {{
            "title": "Math",
            "description": [
               "<skill>": "practice method for the skill with level_message",
               "<skill>": "practice method for the skill with level_message",
            ],
            "title": "Reading and Writing",
            "description": [
               "<skill>": "practice method for the skill with level_message",
               "<skill>": "practice method for the skill with level_message",
            ],
         }}"
      }},
      {{
         "title": "Weekly Structure",
         "description": "Provide a generic overview of the weekly routine. Explain how each weekday will include focused dual-skill practice (one Math and one Reading & Writing skill), starting with the weakest skills early in the week, midweek focus on moderate skills, Fridays for review, Saturdays for timed full-length practice with review, and one Flex Day for rest and adaptability."
      }},
      {{
         "title": "Flex Day Activities", 
         "description": "Suggest actionable, persona-aligned activities that support rest, reflection, cognitive flexibility, and low-pressure practice. Include reflection on errors, experimenting with new tools or techniques, mixed-skill challenges, physical or mindfulness rest activities, and goal-setting for the next week."
      }}
    ]
}}

**Requirements:**
- Return valid JSON only - no additional text
- Keep descriptions concise but personalized 
- Do not include any generic or vague advice. Use the data provided to personalize every recommendation.
- Make Flex Day Activities unique to the student's persona
"""

# %%
PEAK_PHASE_PROMPT = """
You are an expert SAT coach and behavioral science specialist. Write a personalized SAT Peak Phase study plan, using the structured input provided.
Your tone should be **authentic, calm, and professional** — never salesy or exaggerated and matching to **students persona** But not frequently mentioning **students persona** name. Speak to a smart, serious student. The report includes multiple sections and should remain motivational yet concise throughout.

Create a personalized SAT Peak Phase study plan for a student named {student_name}. This student is described as a "{persona_name}", with the following strengths: {persona_strengths}, faces these challenges: {persona_challenges}, and growth strategies: {growth_strategies}.

Here is the student's profile and data:
- Name: {student_name}
- Persona Name: {persona_name}
- Key Strengths: {persona_strengths}
- Areas of Improvement: {persona_challenges}
- Growth Strategies: {growth_strategies}

- Current SAT Score: {current_sat_score_total}
- Goal SAT Score: {goal_score}

- Reading & Writing Skill Accuracies (in priority order): {peak_skills_rw}
- Math Skill Accuracies (in priority order): {peak_skills_math}


Avoid lengthy explanations—prioritize clear, high-impact takeaways over broad commentary - keep it inspiring, focused, and straight to the point. Maintain consistent tone and phrasing across sections to support reliable and repeatable output.

The Peak Phase will take place from {peak_date_range}.

Instructions:
- Do not include '\\n'
- Data should be purely generated based on the Persona details.
- avoid bullet points, lists, or line breaks between sentences.

Purpose:
To simulate real test conditions, stabilize performance, and reinforce confidence. Focusing on mastery.

Key Focus:
- Confidence under pressure
- Endurance for full test conditions
- Mental and emotional control
- Pattern recognition
- Minimize score variance
- Lock in strategy

Using the above data, generate a **Peak Phase** study report divided into the following sections with these exact headings:

1. Weekly Goals  
2. Practice Methods  
3. Weekly Structure  
4. Flex Day Activities

Requirements for each section:

**CRITICAL: Return ONLY valid JSON in exactly this structure:**
Do not wrap the JSON response inside markdown code block tags like ```json or ``` — return only raw JSON :

{{
    title: "Peak Phase",
    description:
    [
      {{
         "title": "Weekly Goals",
         "description": "Summarize clear, specific, outcome-driven goals the student should achieve each week during the Peak Phase. Avoid mentioning how to achieve them or practice methods. Focus on measurable improvements in both Math and Reading & Writing, steady reduction of repeat mistakes, and improved reasoning and accuracy."
      }},
      {{
         "title": "Skill Areas",
         "description":
         [
            {{
               "title": "Math", 
               "description": "List these math skills: {peak_skills_math}"
            }},
            {{
               "title": "Reading & Writing",
               "description": "List these reading and writing skills: {peak_skills_rw}"
            }},
         ]
      }},
      {{
         "title": "Practice Methods",
         "description": "For each subject (Reading & Writing and Math), provide detailed, skill-specific practice methods. Use bullet points (starting with '-') for each skill. Mention the skill name in bold or caps, then describe exactly how the student should practice that skill—aligned with their strengths, challenges, and growth strategies. Ensure routines are structured (daily/weekly) and match the learning style of a disciplined student who thrives on consistency while developing adaptability. The practice methods should align with these growth strategies: {growth_strategies}:
         
         Guidelines:
         - The practice methods should align with these growth strategies: {growth_strategies}
         - The practice method of each skill should align with these skill - summary: {skill_summary_foundation}
         - Generate one sentence for each skill describing the student level and his target from this which includes skill level the student is in and what kind of questions they should concentrate on: {skill_level_message_foundation}

         output should be in this format:
         {{
            "title": "Math",
            "description": [
               "<skill>": "practice method for the skill with level_message",
               "<skill>": "practice method for the skill with level_message",
            ],
            "title": "Reading and Writing",
            "description": [
               "<skill>": "practice method for the skill with level_message",
               "<skill>": "practice method for the skill with level_message",
            ],
         }}"
      }},
      {{
         "title": "Weekly Structure",
         "description": "Provide a generic overview of the weekly routine. Explain how each weekday will include focused dual-skill practice (one Math and one Reading & Writing skill), starting with the weakest skills early in the week, midweek focus on moderate skills, Fridays for review, Saturdays for timed full-length practice with review, and one Flex Day for rest and adaptability."
      }},
      {{
         "title": "Flex Day Activities", 
         "description": "Suggest actionable, persona-aligned activities that support rest, reflection, cognitive flexibility, and low-pressure practice. Include reflection on errors, experimenting with new tools or techniques, mixed-skill challenges, physical or mindfulness rest activities, and goal-setting for the next week."
      }}
    ]
}}

**Requirements:**
- Return valid JSON only - no additional text
- Keep descriptions concise but personalized 
- Do not include any generic or vague advice. Use the data provided to personalize every recommendation.
- Make Flex Day Activities unique to the student's persona
"""

# %%
TWO_SECTIONS = """
You are an expert SAT coach and behavioral science specialist. Write personalized tips and words of encouragement for SAT Phase study plan, using the structured input provided.
Your tone should be **authentic, calm, and professional** — never salesy or exaggerated and matching to **students persona** But not frequently mentioning **students persona** name. Speak to a smart, serious student. The report includes multiple sections and should remain motivational yet concise throughout.

Create personalized tips and words of encouragement for SAT Phase study plan for a student named {student_name}. This student is described as a "{persona_name}", with the following strengths: {persona_strengths}, faces these challenges: {persona_challenges}, and growth strategies: {growth_strategies}.

Here is the student's profile and data:
- Name: {student_name}
- Persona Name: {persona_name}
- Key Strengths: {persona_strengths}
- Areas of Improvement: {persona_challenges}
- Growth Strategies: {growth_strategies}

- Current SAT Score: {current_sat_score_total}
- Goal SAT Score: {goal_score}

- Reading & Writing Skill Accuracies (in priority order): {foundation_skills_rw}
- Math Skill Accuracies (in priority order): {foundation_skills_math}


Avoid lengthy explanations—prioritize clear, high-impact takeaways over broad commentary - keep it inspiring, focused, and straight to the point. Maintain consistent tone and phrasing across sections to support reliable and repeatable output.
Instructions:
- Do not include '\\n'
- Data should be purely generated based on the Persona details.
- avoid bullet points, lists, or line breaks between sentences.

Requirements for each section:

**CRITICAL: Return ONLY valid JSON in exactly this structure:**
Do not wrap the JSON response inside markdown code block tags like ```json or ``` — return only raw JSON :
{{
    {{
        "title": "Tips to Make It Work Best",
        "description": "Offer 5 high-impact, tactical tips designed to improve the student's adaptability to fast-paced, high-stakes test conditions. Each tip must be grounded in specific behavioral strategies, directly aligned with the student’s persona, strengths, challenges, and growth plan. Focus on skills such as real-time decision-making, learning agility, test-day competitiveness, and strategic adaptability. Examples may include structured error reflection, alternating speed vs. accuracy drills, post-practice confidence logging, or peer-based time-boxed simulations. Tips must be concise, practical, and tailored to the student's learning profile. Avoid vague recommendations or flowery language — every tip should be actionable and clearly measurable. Use this context for full personalization: Persona: {persona_name}, Strengths: {persona_strengths}, Challenges: {persona_challenges}, Growth Strategies: {growth_strategies}, Current Score: {current_sat_score_total}, Goal Score: {goal_score}, Phase Timelines: Foundation: {foundation_date_range}, Elevation: {elevation_date_range}, Peak: {peak_date_range}."
        in this format: 
        [
            "Tip 1 text here.",
            "Tip 2 text here.",
            "Tip 3 text here.",
            "Tip 4 text here.",
            "Tip 5 text here."
        ]
    }},
    {{
        "title": "Words of Encouragement",
        "description": "End with 100–150 words of personalized motivation that speaks to the student’s persona, acknowledging their effort and growth potential. Use empowering, positive language."
    }}
}}

**Requirements:**
- Return valid JSON only - no additional text
- Keep descriptions concise but personalized 
- Do not include any generic or vague advice. Use the data provided to personalize every recommendation.
"""

# %%
def list_to_numbered_string(items):
    """Convert list of strings to a numbered string with newlines."""
    return "\n".join([f"{i + 1}. {item}." for i, item in enumerate(items)])

# %%
from datetime import datetime
from datetime import datetime, timedelta
 
 
def format_range(start, end):
    return f"{start.strftime('%Y-%m-%d')} - {end.strftime('%Y-%m-%d')}"
 
def get_three_month_study_phases(start_date_str: str):
    try:
        start_date = datetime.strptime(start_date_str, "%Y-%m-%d").date()
    except ValueError:
        return "Invalid date format. Use YYYY-MM-DD."
 
    foundation_start = start_date
    foundation_end = foundation_start + timedelta(days=30)
 
    elevation_start = foundation_end + timedelta(days=1)
    elevation_end = elevation_start + timedelta(days=29)
 
    peak_start = elevation_end + timedelta(days=1)
    peak_end = peak_start + timedelta(days=29)
 
    return (
        format_range(foundation_start, foundation_end),
        format_range(elevation_start, elevation_end),
        format_range(peak_start, peak_end),
        peak_end.strftime('%Y-%m-%d')
    )
 
def get_custom_study_phases(today_str: str, planned_str: str):
    try:
        today = datetime.strptime(today_str, "%Y-%m-%d").date()
        planned = datetime.strptime(planned_str, "%Y-%m-%d").date()
    except ValueError:
        return "Invalid date format. Use YYYY-MM-DD."
 
    if planned <= today:
        return "Planned date must be after today's date."
 
    diff_days = (planned - today).days
 
    part = diff_days // 3
    remainder = diff_days % 3
 
    foundation_start = today
    foundation_end = foundation_start + timedelta(days=part + (1 if remainder > 0 else 0) - 1)
 
    elevation_start = foundation_end + timedelta(days=1)
    elevation_end = elevation_start + timedelta(days=part + (1 if remainder > 1 else 0) - 1)
 
    peak_start = elevation_end + timedelta(days=1)
    peak_end = planned
 
    return (
        format_range(foundation_start, foundation_end),
        format_range(elevation_start, elevation_end),
        format_range(peak_start, peak_end),
        peak_end.strftime('%Y-%m-%d')
    )
 
def get_study_plan(current_score: int, goal_score: int, today_date_str: str, planned_date_str: str) -> str:
    # Convert string to date
    try:
        today_date = datetime.strptime(today_date_str, "%Y-%m-%d").date()
        planned_date = datetime.strptime(planned_date_str, "%Y-%m-%d").date()
    except ValueError:
        return "Invalid date format. Use YYYY-MM-DD."
 
    score_diff = goal_score - current_score
    if score_diff < 0:
        return "Invalid input: Goal score must be higher than current score."
 
    days_gap = (planned_date - today_date).days
    if days_gap < 0:
        return "Invalid input: Planned date must be in the future."
   
    tone_confident_encouraging = "Use a confident and encouraging tone. Focus on fine-tuning and light improvements."
    tone_motivational_urgent = "Use a motivational tone with urgency. Emphasize structured habits and sustained effort."
    tone_serious_constructive = "Use serious, honest, and constructive tone. Highlight foundational review and disciplined rebuilding."
 
    duration_confident = "60"
    flex_duration_confident = "30"
 
    duration_ambitious = "90"
    flex_duration_ambitious = "60"
 
    duration_aggressive = "120"
    flex_duration_aggressive = "90"
 
    fifth_sentence = ""
 
    # Additionally, include these exact points at the end of the summary:
    conclusion = "Conclude the summary by adding these exact sentences: Considering your upcoming SAT exam date and target score, please write an email to info@sherpalai.com so we can assist you in tailoring your study plan. The default study plan is for three months of total preparation time."
 
    # Case 1: Any score difference and gap < 9 days
    if days_gap < 8:
 
        result = get_three_month_study_phases(today_date_str)
        if isinstance(result, str):
            return result
        else:
            foundation, elevation, peak, end_date = result
 
        duration = duration_confident
        flex_duration = flex_duration_confident
        tone = tone_confident_encouraging
        fifth_sentence = conclusion
       
        return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
 
    # Case 2: 9–31 days
    if 8 <= days_gap <= 31:
        if score_diff <= 100:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
       
        elif 101 <= score_diff <= 250:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_ambitious
            flex_duration= flex_duration_ambitious
            tone = tone_motivational_urgent
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
       
        elif 251 <= score_diff <= 400:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
           
            duration= duration_aggressive
            flex_duration= flex_duration_aggressive
            tone = tone_serious_constructive
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
       
        elif score_diff > 400:
 
            result = get_three_month_study_phases(today_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
           
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
            fifth_sentence = conclusion
           
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
 
    # Case 3: 31–60 days
    if 31 < days_gap <= 60:
        if score_diff <= 500:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
        elif 501 <= score_diff <= 600:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_ambitious
            flex_duration= flex_duration_ambitious
            tone = tone_motivational_urgent
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
       
        elif 601 <= score_diff <= 700:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration= duration_aggressive
            flex_duration= flex_duration_aggressive
            tone = tone_serious_constructive
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
        elif score_diff > 700:
 
            result = get_three_month_study_phases(today_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
            fifth_sentence = conclusion
           
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
 
    # Case 4: 61–90 days
    if 61 <= days_gap <= 90:
        if score_diff <= 800:
           
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
       
        elif 801 <= score_diff <= 900:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_ambitious
            flex_duration= flex_duration_ambitious
            tone = tone_motivational_urgent
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
       
        elif 901 <= score_diff <= 1000:
 
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration= duration_aggressive
            flex_duration= flex_duration_aggressive
            tone = tone_serious_constructive
 
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
        elif score_diff > 1000:
 
            result = get_three_month_study_phases(today_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
            fifth_sentence = conclusion
           
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
 
    # Case 5: >90 days
    if days_gap > 90:
           
            result = get_custom_study_phases(today_date_str, planned_date_str)
            if isinstance(result, str):
                return result
            else:
                foundation, elevation, peak, end_date = result
 
            duration = duration_confident
            flex_duration = flex_duration_confident
            tone = tone_confident_encouraging
           
            return foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence
 
    return "Unexpected case. Please review the inputs."
 
def get_domain_rankings(rw_domains, math_domains):
    # Weightage for each domain
    rw_weightage = {
        "Craft and Structure": 0.28,
        "Information and Ideas": 0.26,
        "Standard English Conventions": 0.26,
        "Expression of Ideas": 0.20
    }
 
    math_weightage = {
        "Algebra": 0.35,
        "Advanced Math": 0.35,
        "Problem-Solving and Data Analysis": 0.15,
        "Geometry and Trigonometry": 0.15
    }
 
    # Helper to compute domain info with priority score
    def process_domains(domains, weight_map):
        domain_info = []
        for d in domains:
            name = d["domain"]
            accuracy = d["accuracy"]
            weight = weight_map.get(name, 0)
            priority_score = (1 - accuracy) * weight
            domain_info.append({
                "name": name,
                "accuracy": accuracy,
                "weightage": weight,
                "priority_score": priority_score
            })
        return domain_info
 
    # Process each category
    rw_processed = process_domains(rw_domains, rw_weightage)
    math_processed = process_domains(math_domains, math_weightage)
 
    # Combine and sort all domains
    combined_domains = rw_processed + math_processed
 
    combined_ranking = sorted(
        combined_domains,
        key=lambda d: (-d['priority_score'], -d['weightage'], d['name'])
    )
 
    rw_ranking = sorted(
        rw_processed,
        key=lambda d: (-d['priority_score'], -d['weightage'], d['name'])
    )
 
    math_ranking = sorted(
        math_processed,
        key=lambda d: (-d['priority_score'], -d['weightage'], d['name'])
    )
 
    return combined_ranking, rw_ranking, math_ranking
# Out:
#   Cell In[36], line 189
#     return result..
#                   ^
# SyntaxError: invalid syntax

# %%
def get_top_and_bottom_skills(skills_data, skill_accuracy_data):
    # Sort by priority (ascending)
    sorted_skills = sorted(skills_data, key=lambda x: int(x["priority"]))
 
    # Helper: Find accuracy from skill_accuracy_data by name
    def get_accuracy(skill_name):
        for item in skill_accuracy_data:
            if item.get("name") == skill_name:
                return item.get("accuracy", "N/A")
        return "N/A"
 
    # Format skill name + accuracy
    def format_with_accuracy(skill_name):
        accuracy = get_accuracy(skill_name)
        return f"{skill_name} ({accuracy}%)"
 
    # Top & bottom 3 skill names
    top_3_names = [skill["name"] for skill in sorted_skills[:3]]
    bottom_3_skills = sorted_skills[-3:]  # Full skill objects for bottom 3
    bottom_3_names = [skill["name"] for skill in bottom_3_skills]
 
    # Format top and bottom 3 with accuracy
    top_3 = [format_with_accuracy(name) for name in top_3_names]
    bottom_3 = [format_with_accuracy(name) for name in bottom_3_names]
 
    # Extract bottom 3 resources
    bottom_3_resources = [
        {
            skill.get("name"): skill.get("educational_resources", [])
        }
        for skill in bottom_3_skills
    ]
 
    return top_3, bottom_3, bottom_3_resources

# %%
def extract_skills(report, skill_type):
    tabs = report.get("tabs", [])
    target_tab = next((tab for tab in tabs if tab.get("tab_name") == "Focus Area"), None)
 
 
    for subject in target_tab.get("subjects", []):
        if subject.get("subject") == skill_type:
            sections = subject.get("sections", [])
            for section in sections:
                if skill_type == "Math":
                    if section.get("section_title") == "Optimizing Problem-Solving: Strengthening Core SAT Math Skills for Maximum Impact":
                        return section.get("section_details", [])
                elif skill_type == "RW":
                    if section.get("section_title") == "Targeted Skill Refinement: Enhancing Efficiency & Accuracy in SAT Reading & Writing":
                        return section.get("section_details", [])
    return []

# %%
def extract_rw_and_math_skills(report):
    rw_skills = []
    math_skills = []
 
    tabs = report.get("tabs", [])
    target_tab = next((tab for tab in tabs if tab.get("tab_name") == "Accuracy Assessment"), None)
 
    for subject in target_tab.get("subjects", []):
        subject_name = subject.get("subject")
        sections = subject.get("sections", [])
        skill_section = next(
            (sec for sec in sections if sec.get("section_title") == "Skill Performance (Accuracy)"),
            None
        )
 
        skills = skill_section.get("section_details", []) if skill_section else []
       
        if subject_name == "RW":
            rw_skills = skills
        elif subject_name == "Math":
            math_skills = skills
 
    return rw_skills, math_skills

# %%
# Gets bottom three resources, this is a static function
 
def get_bottom_three_resources(bottom_three_skills):
    bottom_three_resources = []
    for each_skill in bottom_three_skills:
        bottom_three_resources.append({each_skill["name"]: each_skill["educational_resources"]})
   
    return bottom_three_resources

# %%
def get_skills_in_range(skills_data, start, end):
    # Sort by priority (ascending)
    sorted_skills = sorted(skills_data, key=lambda x: int(x["priority"]))
 
    # Extract slice from sorted skills (convert start/end to 0-based index)
    selected_skills = sorted_skills[start - 1:end]  # inclusive
 
    # Get only the skill names
    skill_names = [skill["name"] for skill in selected_skills]
 
    return skill_names

# %%
# Create the prompt
def generate_template_from_folder(folder_path: str, prompt: str) -> str:
    """Reads input data from a given folder and returns the formatted SAT prompt."""
    input_file = os.path.join(folder_path, "Input_data.json")
 
    with open(input_file, "r", encoding="utf-8") as f:
        data = json.load(f)
 
    report_data = data.get("report", {})
 
    student = report_data.get("user", {})
    persona = report_data.get("persona", {})
    report = report_data.get("sat_readiness_report", {})
 
 
    todays_date = datetime.today().strftime('%Y-%m-%d')
 
    rw_skills = extract_skills(report,"RW")
    rw_skills_accuraccy, math_skills_accuraccy = extract_rw_and_math_skills(report)
 
    rw_top_3, rw_bottom_3, rw_bottom_three_resources = get_top_and_bottom_skills(rw_skills, rw_skills_accuraccy)
    foundation_skills_rw = get_skills_in_range(rw_skills, 1, 3)
    elevation_skills_rw = get_skills_in_range(rw_skills, 4, 6)
    peak_skills_rw = get_skills_in_range(rw_skills, 7, 11)

 
 
    math_skills = extract_skills(report,"Math")
    math_top_3, math_bottom_3, math_bottom_three_resources= get_top_and_bottom_skills(math_skills, math_skills_accuraccy)
    foundation_skills_math = get_skills_in_range(math_skills, 1, 5)
    elevation_skills_math = get_skills_in_range(math_skills, 6, 10)
    peak_skills_math = get_skills_in_range(math_skills, 11, 14)

 
    result = get_study_plan(report["sat_score"], student["goal_score"], todays_date, student["planned_sat_date"])
    if isinstance(result, str):
        print("Error:", result)
    else:
        foundation, elevation, peak, end_date, duration, flex_duration, tone, fifth_sentence = result
 

    foundation_start_date, foundation_end_date = foundation.split(" - ")
    elevation_start_date, elevation_end_date = elevation.split(" - ")
    peak_start_date, peak_end_date = peak.split(" - ")


    # print("rw_bottom_three_resources", rw_bottom_three_resources)
 
    template_data = {
        "student_name": student['preferred_name'],
        "planned_sat_date": student["planned_sat_date"],
        "today_date": todays_date,
        "persona_name": persona["persona_name"],
        "persona_strengths": list_to_numbered_string(persona["key_strengths"]),
        "persona_challenges": list_to_numbered_string(persona["areas_of_improvement"]),
        "growth_strategies": persona["growth_strategies"],
        "current_sat_score_total":report["sat_score"],
        "current_sat_accuracy": report["accuracy_index"],
        "current_sat_time_management": report["time_management"],
        "goal_score": student["goal_score"],
        "math_top_3": list_to_numbered_string(math_top_3),
        "math_bottom_3": list_to_numbered_string(math_bottom_3),
        "rw_top_3": list_to_numbered_string(rw_top_3),
        "rw_bottom_3": list_to_numbered_string(rw_bottom_3),
        "rw_bottom_three_resources":rw_bottom_three_resources,
        "math_bottom_three_resources": math_bottom_three_resources,
        "foundation_phase_rw_skills": list_to_numbered_string(foundation_skills_rw),
        "foundation_phase_math_skills": list_to_numbered_string(foundation_skills_math),
        "foundation_date_range": foundation,
        "elevation_date_range": elevation,
        "peak_date_range": peak,
        "foundation_skills_rw": list_to_numbered_string(foundation_skills_rw),
        "elevation_skills_rw": list_to_numbered_string(elevation_skills_rw),
        "peak_skills_rw": list_to_numbered_string(peak_skills_rw),
        "foundation_skills_math": list_to_numbered_string(foundation_skills_math),
        "elevation_skills_math": list_to_numbered_string(elevation_skills_math),
        "peak_skills_math": list_to_numbered_string(peak_skills_math),
        "foundation_start_date": foundation_start_date,
        "foundation_end_date": foundation_end_date,
        "elevation_start_date": elevation_start_date,
        "elevation_end_date": elevation_end_date,
        "peak_start_date": peak_start_date,
        "peak_end_date": peak_end_date,
    }
 
    if      (prompt == "FOUNDTION_PHASE_PROMPT"):
        return FOUNDTION_PHASE_PROMPT.format(**template_data)
    elif    (prompt == "ELEVATION_PHASE_PROMPT"):
        return ELEVATION_PHASE_PROMPT.format(**template_data)
    elif    (prompt == "PEAK_PHASE_PROMPT"):
         return PEAK_PHASE_PROMPT.format(**template_data)
    elif    (prompt == "TWO_SECTIONS"):
            return TWO_SECTIONS.format(**template_data)

    return Executive_Summary_PROMPT.format(**template_data)

# %%
prompts = ["Executive_Summary_PROMPT", "FOUNDTION_PHASE_PROMPT", "ELEVATION_PHASE_PROMPT", "PEAK_PHASE_PROMPT", "TWO_SECTIONS"]

# %%
# prompts = ["Foundation", "Elevation", "Peak"]

# %%
def invoke_and_save_response(folder_path: str, prefix: str, llm) -> None:
    result_json = {}
    for prompt_name in prompts:
        prompt = generate_template_from_folder(folder_path, prompt_name)

        response = llm.invoke(prompt)
        content = response.content if hasattr(response, "content") else response

        # print("*******************", prompt_name, "************************")
        print(f"Response: {content}")
        result_json[prompt_name] = json.loads(content)

    # Save content to a text file
    output_file_path = folder_path+"\Detailed_Study_Plan.json"
    with open(output_file_path, "w", encoding="utf-8") as f:
        f.write(json.dumps(result_json, indent=4, ensure_ascii=False))

    # # Save the response to a file with prefix
    # input_file_path = os.path.join(folder_path, "Input_data.json")
    # with open(input_file_path, "r", encoding="utf-8") as f:
    #     data = json.load(f)

    # name = data["user"]["first_name"]
    # output_filename = f"{name}_{prefix}.json"
    # output_file_path = os.path.join(folder_path, output_filename)

    # # Delete the file if it exists
    # if os.path.exists(output_file_path):
    #     os.remove(output_file_path)

    # # Directly write the content string to the file
    # with open(output_file_path, "w", encoding="utf-8") as out_f:
    #     out_f.write(content)
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Manideep S\AppData\Local\Temp\ipykernel_18172\1363857730.py:14: SyntaxWarning: invalid escape sequence '\D'
#   output_file_path = folder_path+"\Detailed_Study_Plan.json"

# %%
folders = ["IshanaPotti", "Meenakshi", "RohanByali"]#, "Govind", "Ishan", "Jevinn", "Ronit", "Sumedh", "Toni", "Zoha"]

# %%
from tqdm import tqdm

for folder in tqdm(folders, desc="Folders Progress"):
    folder_path = r"C:\Users\Manideep S\Downloads\L@\SAT Paid Report\Users_data\{folder}".format(folder=folder)

    for i in tqdm(range(1, 2), desc=f"Processing {folder}", leave=False):
        prefix = str(i)
        invoke_and_save_response(folder_path, prefix, llm)
# Out:
# Folders Progress:   0%|          | 0/3 [00:00<?, ?it/s]
# Response: {
#   "Executive Summary": "Ishana is a curious and adaptive learner who excels at experimenting with new strategies but may face challenges in maintaining consistent focus on long-term mastery. Currently, Ishana has a solid SAT score of 1440 with an overall accuracy of 80% and a time management score of 49. This balance of strengths and areas for growth highlights the potential for significant improvement by deepening focus on key skills and developing a steady study routine. With targeted effort, Ishana is well-positioned to reach the realistic target score of 1590 by June 2025.",
#   "Key Strengths": {
#     "Reading & Writing": [
#       "Words in Context (66%)",
#       "Form, Structure, and Sense (47%)",
#       "Command of Evidence - Textual (68%)"
#     ],
#     "Math": [
#       "Nonlinear functions (78%)",
#       "Nonlinear equations in one variable and systems of equations in two variables (84%)",
#       "Systems of two linear equations in two variables (78%)"
#     ]
#   },
#   "Focus Areas for Growth": {
#     "Reading & Writing": [
#       "Central Ideas and Details (93%)",
#       "Command of Evidence - Quantitative (87%)",
#       "Cross-text Connections (77%)"
#     ],
#     "Math": [
#       "Percentages (78%)",
#       "Ratios, rates, proportional relationships, and units (92%)",
#       "Right triangles and trigonometry (83%)"
#     ]
#   },
#   "Bottom 3 Skills Resources:": {
#     "Reading & Writing": [
#       "• Central Ideas and Details - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-information-and-ideas/x0d47bcec73eb6c4b:central-ideas-and-details/a/central-ideas-and-details-lesson",
#       "• Command of Evidence - Quantitative - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-information-and-ideas/x0d47bcec73eb6c4b:command-of-evidence-quantitative/a/command-of-evidence-quantitative-lesson",
#       "• Cross-text Connections - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-craft-and-structure/x0d47bcec73eb6c4b:cross-text-connections/a/cross-text-connections-lesson"
#     ],
#     "Math": [
#       "• Percentages - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:percentages-easier/a/v2-sat-lesson-percentages",
#       "• Ratios, rates, proportional relationships, and units - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:ratios-rates-and-proportions-easier/a/v2-sat-lesson-ratios-rates-and-proportions",
#       "• Ratios, rates, proportional relationships, and units - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:unit-conversion-easier/a/v2-sat-lesson-unit-conversion",
#       "• Right triangles and trigonometry - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:geometry-and-trigonometry-easier/x0fcc98a58ba3bea7:right-triangle-trigonometry-easier/a/v2-sat-lesson-right-triangle-trigonometry"
#     ]
#   }
# }
# Response: {
#   "title": "Foundation Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve measurable improvement in accuracy and reasoning across prioritized Math and Reading & Writing skills. Reduce repeat mistakes by reflecting on errors and applying feedback consistently. Build steady comprehension of nonlinear and linear math concepts while enhancing vocabulary in context and command of textual evidence. Establish a baseline of disciplined study habits with clear short-term targets and maintain focus through weekly self-assessments."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Nonlinear functions. 2. Nonlinear equations in one variable and systems of equations in two variables. 3. Systems of two linear equations in two variables. 4. Linear functions. 5. Linear equations in two variables."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Words in Context. 2. Form, Structure, and Sense. 3. Command of Evidence - Textual."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Nonlinear functions": "Dedicate daily practice sessions to solving nonlinear function problems using a ‘method of the week’ approach, committing to mastering one problem-solving strategy before moving to another. Use habit trackers to log accuracy and time spent, reflecting weekly on progress to adjust methods if needed.",
#           "Nonlinear equations in one variable and systems of equations in two variables": "Engage in targeted problem sets focusing on these equations, applying trial and error to test different solving techniques. Schedule midweek checkpoints to review errors and refine approaches, ensuring deeper understanding rather than surface-level attempts.",
#           "Systems of two linear equations in two variables": "Practice solving systems with consistent routines, alternating between substitution and elimination methods weekly to maintain novelty while building mastery. Use self-assessments to identify sticking points and focus follow-up practice accordingly.",
#           "Linear functions": "Incorporate daily short drills emphasizing interpretation and manipulation of linear functions, pairing conceptual questions with applied problems to strengthen connections between ideas.",
#           "Linear equations in two variables": "Use structured weekly problem sets with increasing complexity, reflecting on mistakes and experimenting with alternative solving paths to deepen conceptual clarity."
#         },
#         "Reading and Writing": {
#           "Words in Context": "Adopt a ‘method of the week’ by focusing on one vocabulary acquisition tool or strategy, such as context clues or root analysis, practicing daily with passages and tracking progress. Reflect weekly on which methods yield best retention and comprehension.",
#           "Form, Structure, and Sense": "Engage in daily close reading exercises emphasizing passage structure and logical flow, using annotation and summarization techniques. Commit to one analytical approach per week, reviewing effectiveness through weekly self-assessments.",
#           "Command of Evidence - Textual": "Practice identifying and justifying textual evidence in daily exercises, experimenting with different note-taking or mapping strategies each week. Use feedback loops to refine evidence selection and explanation skills, ensuring steady improvement."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday includes focused dual-skill practice pairing one Math and one Reading & Writing skill, beginning the week with weakest skills to build foundational strength. Midweek sessions target moderate skills with varied problem types to maintain engagement. Fridays are reserved for comprehensive review of the week’s work, consolidating learning and addressing persistent errors. Saturdays involve timed full-length practice tests followed by detailed review to build stamina and accuracy. Sundays serve as a Flex Day for rest, reflection, and adaptive learning activities."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Use this day for low-pressure reflection on errors made during the week, analyzing patterns and insights gained. Experiment with new learning tools or techniques aligned with your curiosity, committing to one for the upcoming week. Engage in mixed-skill challenges that integrate Math and Reading & Writing to foster cognitive flexibility. Incorporate mindfulness or physical activities to recharge focus and reduce stress. Set clear, achievable goals for the next week, balancing novelty with disciplined follow-through."
#     }
#   ]
# }
# Response: {
#   "title": "Elevation Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve measurable improvement in accuracy and reasoning for second-tier Math skills, particularly equivalent expressions and linear inequalities, while steadily reducing careless errors. In Reading & Writing, enhance precision in rhetorical synthesis and transitions, with a focus on deeper inference skills. Demonstrate consistent progress through timed practice, showing improved cognitive flexibility and strategic application under moderate time pressure."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "Equivalent expressions. Linear inequalities in one or two variables. Area and volume. Lines, angles, and triangles. One-variable data: Distributions and measures of center and spread."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "Rhetorical Synthesis. Transitions. Inferences."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Equivalent expressions": "Commit to a focused week mastering one new approach to simplifying and manipulating expressions, using timed drills to build fluency and reduce careless slips. Reflect daily on errors and adjust strategies accordingly.",
#           "Linear inequalities in one or two variables": "Practice solving and graphing inequalities with increasing complexity, integrating real-world problem contexts. Use weekly checkpoints to assess accuracy and adapt methods if progress stalls.",
#           "Area and volume": "Apply formulas in varied problem sets under timed conditions, emphasizing conceptual connections between shapes. Track error patterns to refine calculation steps.",
#           "Lines, angles, and triangles": "Engage with targeted geometry problems that require multi-step reasoning, using visual aids and self-explanation to deepen understanding.",
#           "One-variable data: Distributions and measures of center and spread": "Analyze data sets through practice questions, focusing on interpreting and calculating measures accurately. Use weekly self-assessments to monitor improvement."
#         },
#         "Reading and Writing": {
#           "Rhetorical Synthesis": "Practice integrating multiple viewpoints in passages through structured annotation and summary exercises. Commit to one synthesis strategy per week, reflecting on effectiveness and adjusting as needed.",
#           "Transitions": "Work on identifying and applying varied transition types in context, using timed sentence and paragraph-level exercises. Use habit tracking to maintain daily practice consistency.",
#           "Inferences": "Develop inference skills by analyzing subtle textual clues in practice passages, followed by reflective journaling on reasoning processes. Use weekly reviews to identify patterns in mistakes and refine approaches."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday includes focused dual-skill sessions pairing one Math and one Reading & Writing skill, starting Monday with weakest areas like equivalent expressions and rhetorical synthesis to build foundational accuracy. Midweek shifts to moderate skills such as linear inequalities and transitions to deepen application under moderate time pressure. Fridays are dedicated to comprehensive review and error analysis to reinforce learning and adjust strategies. Saturdays involve timed full-length practice tests followed by detailed performance reviews to simulate test conditions and build endurance. Sunday serves as a Flex Day for rest, reflection, and adaptive learning."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Engage in reflective error analysis by reviewing past mistakes to identify learning patterns without pressure. Experiment with a new study tool or technique for one skill area, committing to a trial but allowing flexibility to pivot if ineffective. Tackle mixed-skill challenges combining Math and Reading & Writing to stimulate cognitive flexibility. Incorporate mindfulness or light physical activity to recharge focus. Set clear, short-term goals for the upcoming week, balancing curiosity with disciplined follow-through."
#     }
#   ]
# }
# Response: {
#   "title": "Peak Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve measurable improvement in accuracy and reasoning for priority Math skills, particularly linear equations and percentages, while steadily reducing errors in ratios and trigonometry. In Reading & Writing, increase precision in identifying boundaries and text structure, deepen understanding of central ideas, and enhance command of evidence with quantitative reasoning. Maintain consistent performance under timed conditions, minimize score variance, and build endurance for full-length tests."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Linear equations in one variable. 2. Percentages. 3. Ratios, rates, proportional relationships, and units. 4. Right triangles and trigonometry."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Boundaries. 2. Text Structure and Purpose. 3. Central Ideas and Details. 4. Command of Evidence - Quantitative. 5. Cross-text Connections."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Linear equations in one variable": "Commit to a focused week mastering linear equations by solving progressively complex problems daily, reflecting on errors, and using a habit tracker to monitor consistency. Use trial and error to test different solving strategies, then select the most efficient approach to reinforce mastery.",
#           "Percentages": "Apply percentage problems in varied contexts each day, experimenting with visual aids or real-world examples to deepen understanding. Track progress with weekly self-assessments and adjust methods based on feedback to build steady expertise.",
#           "Ratios, rates, proportional relationships, and units": "Dedicate practice sessions to connecting ratios and rates with real-life scenarios, using method-of-the-week tools like ratio tables or unit conversion apps. Commit to mastering one tool per week, reflecting on its effectiveness before moving on.",
#           "Right triangles and trigonometry": "Engage in daily problem sets emphasizing pattern recognition and formula application, using spaced repetition and self-quizzing. Reflect on mistakes to pivot strategies and solidify understanding over the week."
#         },
#         "Reading and Writing": {
#           "Boundaries": "Practice identifying textual boundaries through daily passage segmentation exercises, experimenting with annotation techniques. Use weekly checkpoints to evaluate progress and refine your approach for clarity and precision.",
#           "Text Structure and Purpose": "Explore different text structures by analyzing passages with a new method each week, such as graphic organizers or mind maps. Commit to mastering one method per week, reflecting on how it enhances comprehension and retention.",
#           "Central Ideas and Details": "Engage in targeted exercises that require extracting central ideas and supporting details, using trial and error to test different note-taking strategies. Track accuracy improvements weekly and adjust methods accordingly.",
#           "Command of Evidence - Quantitative": "Practice interpreting quantitative evidence in reading passages daily, using varied tools like charts or data visualization apps. Commit to a single tool per week, assessing its impact on your reasoning and adjusting as needed.",
#           "Cross-text Connections": "Develop skills by comparing paired passages weekly, experimenting with different frameworks for synthesis and contrast. Use self-assessments to identify the most effective approach and build consistency."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday begins with focused dual-skill practice pairing one Math and one Reading & Writing skill, starting Monday with the weakest areas to maximize early-week gains. Midweek sessions target moderate skills with increasing complexity. Fridays are reserved for comprehensive review and error analysis to reinforce learning. Saturdays simulate full-length timed tests under realistic conditions, followed by detailed review to stabilize performance and build endurance. Sundays serve as a Flex Day to support rest, reflection, and adaptive learning."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Engage in reflective journaling on errors and breakthroughs to deepen insight and reinforce learning. Experiment with new study tools or techniques for upcoming weeks, committing to one for mastery. Tackle mixed-skill challenges at a relaxed pace to maintain cognitive flexibility. Incorporate mindfulness or light physical activity to recharge mental stamina. Set clear, short-term goals for the following week to maintain focus and motivation."
#     }
#   ]
# }
# Folders Progress:  33%|███▎      | 1/3 [00:55<01:51, 55.59s/it]
# Response: {
#     "Tips to Make It Work Best": [
#         "Set a clear ‘method of the week’ to focus on mastering one new strategy fully before moving on, balancing your curiosity with depth.",
#         "Use short, timed practice sessions alternating between speed and accuracy to sharpen decision-making under pressure while maintaining precision.",
#         "After each practice, spend 10 minutes reflecting on errors and successes to identify patterns and adjust your approach thoughtfully.",
#         "Incorporate weekly self-assessments with specific goals to maintain consistent progress and prevent drifting between strategies.",
#         "Track your study habits daily with a habit tracker to build discipline and reward yourself for following through, reinforcing steady routines."
#     ],
#     "Words of Encouragement": "Your natural curiosity and ability to learn through experimentation are powerful assets on this journey. Embracing mistakes as opportunities to grow will continue to deepen your understanding and sharpen your skills. Remember, the key to reaching your goal score lies in pairing your love for new ideas with a steady, focused plan. By committing to mastering one approach at a time and reflecting regularly on your progress, you’ll build the consistency needed to excel. Trust your adaptability and creativity—they will help you pivot effectively when challenges arise. Keep your goals in sight and celebrate each step forward; your thoughtful, reflective approach is exactly what will carry you to success."
# }
# Response: {
#   "Executive Summary": "Meenakshi, known as Persistent Hiker, is a steady yet comfort-seeking learner who balances well-being with academic goals. Currently scoring 1510 on the SAT with 84% accuracy and a time management score of 47, she demonstrates strong consistency and calmness under pressure. Her approach favors long-term growth and emotional stability, though she may shy away from challenges that push her limits. This balance positions her well for steady improvement toward her realistic target score of 1590 by June 2025.",
#   "Key Strengths": {
#     "Reading & Writing": [
#       "Words in Context (65%)",
#       "Transitions (72%)",
#       "Form, Structure, and Sense (69%)"
#     ],
#     "Math": [
#       "Nonlinear functions (93%)",
#       "Systems of two linear equations in two variables (83%)",
#       "Linear equations in two variables (83%)"
#     ]
#   },
#   "Focus Areas for Growth": {
#     "Reading & Writing": [
#       "Rhetorical Synthesis (94%)",
#       "Command of Evidence - Quantitative (100%)",
#       "Cross-text Connections (93%)"
#     ],
#     "Math": [
#       "Linear equations in one variable (92%)",
#       "One-variable data: Distributions and measures of center and spread (78%)",
#       "Ratios, rates, proportional relationships, and units (93%)"
#     ]
#   },
#   "Bottom 3 Skills Resources:": {
#     "Reading & Writing": [
#       "• Rhetorical Synthesis - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-expression-of-ideas-and-standard-english-conventions/x0d47bcec73eb6c4b:rhetorical-synthesis/a/rhetorical-synthesis-lesson",
#       "• Command of Evidence - Quantitative - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-information-and-ideas/x0d47bcec73eb6c4b:command-of-evidence-quantitative/a/command-of-evidence-quantitative-lesson",
#       "• Cross-text Connections - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-craft-and-structure/x0d47bcec73eb6c4b:cross-text-connections/a/cross-text-connections-lesson"
#     ],
#     "Math": [
#       "• Linear equations in one variable - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:algebra-easier/x0fcc98a58ba3bea7:solving-linear-equations-and-inequalities-easier/a/v2-sat-lesson-solving-linear-equations-and-inequalities",
#       "• One-variable data: Distributions and measures of center and spread - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:center-spread-and-shape-of-distributions-easier/a/v2-sat-lesson-center-spread-and-shape-of-distributions",
#       "• Ratios, rates, proportional relationships, and units - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:ratios-rates-and-proportions-easier/a/v2-sat-lesson-ratios-rates-and-proportions",
#       "• Ratios, rates, proportional relationships, and units - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:unit-conversion-easier/a/v2-sat-lesson-unit-conversion"
#     ]
#   }
# }
# Response: {
#   "title": "Foundation Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve steady improvement in accuracy across prioritized Math and Reading & Writing skills, reducing repeated errors through deliberate practice. Build a consistent study rhythm that balances challenge with calm, fostering deeper conceptual understanding. Begin closing skill gaps in nonlinear functions and words in context while enhancing reasoning and precision. Cultivate confidence by tracking small wins and maintaining emotional balance throughout the week."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Nonlinear functions. 2. Systems of two linear equations in two variables. 3. Linear equations in two variables. 4. Linear functions. 5. Right triangles and trigonometry."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Words in Context. 2. Transitions. 3. Form, Structure, and Sense."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Nonlinear functions": "Engage with progressively challenging nonlinear function problems daily, starting with guided examples and moving to independent problem sets. Track accuracy and reward milestones to maintain motivation without pressure.",
#           "Systems of two linear equations in two variables": "Practice solving systems through varied methods (substitution, elimination) in short, focused sessions. Incorporate peer discussion or group challenges weekly to gently increase intensity and deepen understanding.",
#           "Linear equations in two variables": "Use incremental problem sets emphasizing conceptual clarity and error analysis. Reflect on mistakes calmly to identify patterns and adjust strategies.",
#           "Linear functions": "Apply linear function concepts to real-world scenarios in practice questions, gamifying progress by unlocking more complex problems as accuracy improves.",
#           "Right triangles and trigonometry": "Introduce trigonometric concepts through visual aids and stepwise problem solving, gradually increasing difficulty while maintaining a stress-free pace."
#         },
#         "Reading and Writing": {
#           "Words in Context": "Daily practice with vocabulary in context using curated passages, focusing on subtle meaning shifts. Use flashcards and mini-quizzes to gamify learning and celebrate small wins.",
#           "Transitions": "Analyze transition usage in short reading passages, then practice inserting or correcting transitions in writing exercises. Reflect on how transitions affect flow and clarity.",
#           "Form, Structure, and Sense": "Work through structured reading comprehension exercises emphasizing passage organization and logic. Engage in weekly peer review sessions to discuss interpretations and build confidence."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday includes focused dual-skill practice pairing one Math and one Reading & Writing skill, beginning the week with the most challenging areas like nonlinear functions and words in context. Midweek shifts to moderate skills such as systems of equations and transitions. Fridays are dedicated to review and reflection on progress and errors. Saturdays involve timed full-length practice tests followed by calm, detailed review sessions. Sundays serve as a Flex Day to rest, reflect, and adapt the plan as needed."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Engage in low-pressure reflection on errors made during the week, journaling insights to distinguish between peaceful balance and complacency. Experiment with new study tools or techniques in a relaxed setting to foster cognitive flexibility. Participate in mixed-skill challenges with peers to gently elevate motivation. Incorporate mindfulness or light physical activity to support emotional stability. Set clear, achievable goals for the upcoming week to maintain steady, sustainable growth."
#     }
#   ]
# }
# Response: {
#   "title": "Elevation Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve measurable improvement in accuracy and reasoning for nonlinear equations and text structure analysis. Reduce careless errors by at least 20% across all practiced skills. Strengthen command of evidence and equivalent expressions through consistent application under moderate time pressure. Enhance cognitive flexibility by adapting strategies during timed practice and review cycles. Maintain steady progress without sacrificing emotional balance or well-being."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Nonlinear equations in one variable and systems of equations in two variables. 2. Equivalent expressions. 3. Linear inequalities in one or two variables. 4. Percentages. 5. Area and volume."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Text Structure and Purpose. 2. Inferences. 3. Command of Evidence - Textual."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Nonlinear equations in one variable and systems of equations in two variables": "Engage in daily micro-challenges that increase in complexity, starting with guided problem sets and progressing to timed mixed problems. Track accuracy and speed, rewarding milestones to maintain motivation while reflecting on errors to identify patterns.",
#           "Equivalent expressions": "Practice transforming expressions through incremental difficulty levels, incorporating peer comparison sessions to gently introduce competitive elements. Use gamified quizzes to reinforce recognition and manipulation of equivalent forms.",
#           "Linear inequalities in one or two variables": "Apply stepwise problem-solving drills with immediate feedback, gradually reducing time limits. Pair with peers for occasional collaborative problem sets to encourage strategic discussion and deeper understanding.",
#           "Percentages": "Integrate percentage problems into daily warm-ups, increasing challenge by combining with other math concepts. Use progress tracking to celebrate small wins and maintain steady engagement.",
#           "Area and volume": "Work through layered practice sets that start with formula recall and move toward complex application problems. Reflect on mistakes in a calm, structured review to reinforce learning without pressure."
#         },
#         "Reading and Writing": {
#           "Text Structure and Purpose": "Analyze passages daily with a focus on identifying organizational patterns and author intent. Use tiered difficulty levels and timed drills to build speed and precision, incorporating self-assessment to balance challenge with emotional steadiness.",
#           "Inferences": "Practice inference questions through gradual exposure to increasingly subtle textual clues. Use group discussions with slightly more intense peers to explore multiple interpretations, fostering cognitive flexibility and confidence.",
#           "Command of Evidence - Textual": "Engage in targeted exercises that require locating and justifying evidence under timed conditions. Gamify progress with badges for accuracy and speed, encouraging reflection on the difference between careful reasoning and complacency."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday begins with focused dual-skill practice pairing one Math and one Reading & Writing skill, starting Monday and Tuesday with the weakest areas to build foundational strength. Wednesday and Thursday shift to moderate skills to reinforce and layer complexity. Friday is dedicated to comprehensive review and error analysis to consolidate learning. Saturday involves a timed full-length practice test followed by a calm, structured review session to identify growth areas. Sunday serves as a Flex Day for rest, reflection, and adaptive practice aligned with personal balance."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Engage in low-pressure reflection on errors from the week, journaling insights to distinguish between peace and complacency. Experiment with new study tools or techniques in a playful, exploratory manner. Participate in mixed-skill challenges with peers to gently stretch comfort zones without competition stress. Incorporate mindfulness or light physical activity such as walking or yoga to support mental clarity. Set clear, achievable goals for the upcoming week to maintain steady, sustainable progress."
#     }
#   ]
# }
# Response: {
#   "title": "Peak Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve steady improvement in accuracy and reasoning across prioritized Math and Reading & Writing skills, reducing repeat errors by at least 10% each week. Build endurance to maintain focus and precision through full-length timed sections. Strengthen confidence under pressure by simulating test conditions regularly. Develop consistent mental and emotional control strategies to minimize score variance and lock in effective test-taking patterns."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Lines, angles, and triangles. 2. Linear equations in one variable. 3. One-variable data: Distributions and measures of center and spread. 4. Ratios, rates, proportional relationships, and units."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Boundaries. 2. Central Ideas and Details. 3. Rhetorical Synthesis. 4. Command of Evidence - Quantitative. 5. Cross-text Connections."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Lines, angles, and triangles": "Engage in daily micro-challenges that increase in complexity, starting with straightforward problems and advancing to multi-step geometry questions. Track progress visually to gamify improvement and reward consistent accuracy. Reflect weekly on errors to distinguish between comfort and growth zones.",
#           "Linear equations in one variable": "Practice solving equations with incremental difficulty, incorporating timed drills to build endurance. Pair with peers for occasional problem-solving sessions that introduce mild competitive elements to gently push limits without disrupting balance.",
#           "One-variable data: Distributions and measures of center and spread": "Use real-world data sets to interpret and analyze distributions, gradually increasing complexity. Incorporate self-assessment checkpoints to recognize patterns and reinforce confidence in quantitative reasoning.",
#           "Ratios, rates, proportional relationships, and units": "Apply concepts through layered problem sets that require connecting multiple ratio and rate scenarios. Celebrate small wins by tracking streaks of correct answers and reflecting on strategy adjustments."
#         },
#         "Reading and Writing": {
#           "Boundaries": "Practice identifying textual boundaries through focused daily passages, progressively increasing length and complexity. Use gamified checkpoints to reward recognition speed and accuracy, encouraging deliberate stretching beyond comfort zones.",
#           "Central Ideas and Details": "Engage in structured exercises that require pinpointing main ideas and supporting details under timed conditions. Incorporate peer discussions to deepen understanding and introduce slight challenge through collaborative reflection.",
#           "Rhetorical Synthesis": "Work on synthesizing information from multiple sources with incremental difficulty, framing each task as an opportunity to build analytical resilience. Use self-reflection prompts to differentiate between peaceful mastery and complacency.",
#           "Command of Evidence - Quantitative": "Practice extracting and interpreting quantitative evidence within reading passages, gradually increasing complexity and integrating mixed-format questions. Reward progress with small milestones to maintain motivation.",
#           "Cross-text Connections": "Develop skills by comparing and contrasting paired texts, focusing on subtle connections and thematic links. Occasionally collaborate with peers to introduce dynamic perspectives and mild challenge."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday begins with focused dual-skill practice pairing one Math and one Reading & Writing skill, starting Monday and Tuesday with the weakest areas to maximize growth potential. Wednesday and Thursday focus on moderate skills to build momentum. Friday is dedicated to comprehensive review and error analysis. Saturday involves a full-length timed practice test under simulated conditions, followed by detailed review to reinforce endurance and strategy. Sunday serves as a Flex Day for rest, reflection, and adaptive activities aligned with maintaining balance."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Engage in low-pressure reflection on errors from the week, journaling insights to distinguish between peace and complacency. Experiment with new study tools or techniques in short, playful sessions to spark curiosity without stress. Participate in mixed-skill challenges that encourage cognitive flexibility without time pressure. Incorporate mindfulness practices or light physical activity such as walking or yoga to support emotional stability. Set clear, achievable goals for the upcoming week to maintain steady, sustainable progress."
#     }
#   ]
# }
# Folders Progress:  67%|██████▋   | 2/3 [01:56<00:59, 59.01s/it]
# Response: {
#     "Tips to Make It Work Best": [
#         "Incorporate brief, focused micro-challenges into your study sessions that slightly push your limits, such as timed practice on nonlinear functions or words in context, to build resilience without overwhelming your balance.",
#         "Use a gamified approach by setting clear, incremental goals for each study topic and reward yourself with small acknowledgments for each milestone, reinforcing steady progress and maintaining motivation.",
#         "Alternate between accuracy-focused drills and timed exercises to develop adaptability, ensuring you remain deliberate but also comfortable with making decisions under time constraints.",
#         "After each practice session, reflect calmly on errors by journaling what was challenging and how you approached it, framing mistakes as growth opportunities rather than stress triggers.",
#         "Engage occasionally with peers who have a slightly more intense prep style in structured, time-boxed group challenges to boost momentum and gently stretch your competitive edge without disrupting your inner harmony."
#     ],
#     "Words of Encouragement": "Your steady, thoughtful approach is a powerful asset as you prepare for the SAT. Remember that true balance comes from knowing when to maintain calm and when to push yourself just a bit further. Each small challenge you embrace is a step toward unlocking your full potential, not a threat to your well-being. Your maturity and self-awareness will guide you through moments of discomfort, transforming them into meaningful growth. Trust in your ability to progress consistently and deliberately, knowing that sustainable improvement is built on patience and persistence. Keep valuing your mental clarity and emotional stability—they are the foundation that will support your success as you reach for your goal score."
# }
# Response: {
#   "Executive Summary": "Rohan is a tenacious yet occasionally discouraged learner, demonstrating steady effort and resilience despite challenges in seeing immediate progress. Currently, his SAT total score is 640, with an overall accuracy of 48% and a time management score of 35. His strengths lie in persistence and intrinsic motivation, which fuel consistent work even when results are slow. However, he may struggle with motivation dips when progress feels unseen and can benefit from strategic adjustments to improve efficiency. With a realistic target score of 1590 by June 2025, focused practice and regular feedback will be key to unlocking his potential and maintaining momentum on this long journey.",
#   "Key Strengths": {
#     "Reading & Writing": [
#       "Form, Structure, and Sense (20%)",
#       "Words in Context (40%)",
#       "Boundaries (39%)"
#     ],
#     "Math": [
#       "Nonlinear functions (71%)",
#       "Systems of two linear equations in two variables (33%)",
#       "Linear equations in two variables (45%)"
#     ]
#   },
#   "Focus Areas for Growth": {
#     "Reading & Writing": [
#       "Central Ideas and Details (41%)",
#       "Inferences (56%)",
#       "Cross-text Connections (40%)"
#     ],
#     "Math": [
#       "One-variable data: Distributions and measures of center and spread (56%)",
#       "Right triangles and trigonometry (67%)",
#       "Ratios, rates, proportional relationships, and units (78%)"
#     ]
#   },
#   "Bottom 3 Skills Resources:": {
#     "Reading & Writing": [
#       "• Central Ideas and Details - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-information-and-ideas/x0d47bcec73eb6c4b:central-ideas-and-details/a/central-ideas-and-details-lesson",
#       "• Inferences - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-information-and-ideas/x0d47bcec73eb6c4b:inferences/a/inferences-lesson",
#       "• Cross-text Connections - https://www.khanacademy.org/test-prep/sat-reading-and-writing/x0d47bcec73eb6c4b:foundations-craft-and-structure/x0d47bcec73eb6c4b:cross-text-connections/a/cross-text-connections-lesson"
#     ],
#     "Math": [
#       "• One-variable data: Distributions and measures of center and spread - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:center-spread-and-shape-of-distributions-easier/a/v2-sat-lesson-center-spread-and-shape-of-distributions",
#       "• Right triangles and trigonometry - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:geometry-and-trigonometry-easier/x0fcc98a58ba3bea7:right-triangle-trigonometry-easier/a/v2-sat-lesson-right-triangle-trigonometry",
#       "• Ratios, rates, proportional relationships, and units - https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:ratios-rates-and-proportions-easier/a/v2-sat-lesson-ratios-rates-and-proportions https://www.khanacademy.org/test-prep/v2-sat-math/x0fcc98a58ba3bea7:problem-solving-and-data-analysis-easier/x0fcc98a58ba3bea7:unit-conversion-easier/a/v2-sat-lesson-unit-conversion"
#     ]
#   }
# }
# Response: {
#   "title": "Foundation Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Achieve measurable improvements in accuracy and reasoning across prioritized Math and Reading & Writing skills each week. Reduce repeat mistakes steadily by identifying patterns and applying targeted corrections. Build confidence through consistent progress tracking and demonstrate clearer understanding of nonlinear functions, systems of equations, and core reading comprehension elements. Strengthen foundational skills to create a reliable baseline for future phases."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Nonlinear functions. 2. Systems of two linear equations in two variables. 3. Linear equations in two variables. 4. Nonlinear equations in one variable and systems of equations in two variables. 5. Percentages."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Form, Structure, and Sense. 2. Words in Context. 3. Boundaries."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Nonlinear functions": "Engage daily with progressively challenging nonlinear function problems, focusing on concept clarity and error analysis. Track accuracy visually with weekly charts and reflect on problem-solving approaches to identify effective strategies or necessary adjustments.",
#           "Systems of two linear equations in two variables": "Practice solving systems methodically, alternating between substitution and elimination techniques. Use peer or mentor feedback to validate solutions and adapt methods if progress plateaus. Celebrate milestones like streaks of correct solutions to maintain motivation.",
#           "Linear equations in two variables": "Incorporate daily drills emphasizing precision and speed. Reflect weekly on common errors and adjust practice focus accordingly. Use visual progress indicators to reinforce persistence and adaptability.",
#           "Nonlinear equations in one variable and systems of equations in two variables": "Integrate mixed problem sets weekly to build flexibility. After each session, journal reflections on what strategies worked and where to pivot. Share progress with a mentor to gain perspective and encouragement.",
#           "Percentages": "Dedicate short, focused sessions to percentage problems, emphasizing real-world applications. Track improvement through weekly summaries and adjust practice intensity based on error trends."
#         },
#         "Reading and Writing": {
#           "Form, Structure, and Sense": "Analyze passages daily, focusing on sentence and paragraph structure. Use annotated reading to highlight key elements and track comprehension improvements visually. Reflect on challenging sections to refine approach and share insights with peers.",
#           "Words in Context": "Practice vocabulary in context through targeted exercises, noting progress with weekly word mastery charts. Use reflection prompts to evaluate which strategies enhance retention and adjust study methods accordingly.",
#           "Boundaries": "Work on punctuation and grammar boundaries with consistent daily practice. Review errors systematically and celebrate small wins publicly or privately to sustain motivation. Pair with a mentor for feedback and to gain perspective on growth."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Each weekday includes focused dual-skill practice pairing one Math and one Reading & Writing skill, starting the week with weakest areas to maximize early gains. Midweek shifts to moderate skills to maintain momentum. Fridays are dedicated to comprehensive review and error analysis. Saturdays involve timed full-length practice tests followed by detailed review sessions. Sundays serve as a Flex Day for rest, reflection, and adaptive learning."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Engage in low-pressure reflection on errors and progress, using visual growth charts to appreciate incremental gains. Experiment with new study tools or alternate problem-solving techniques to foster adaptability. Attempt mixed-skill challenges at a relaxed pace to build cognitive flexibility. Incorporate mindfulness or physical rest activities to recharge focus. Set clear, purpose-driven goals for the upcoming week to maintain intrinsic motivation and resilience."
#     }
#   ]
# }
# Response: {
#   "title": "Elevation Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Each week, steadily improve accuracy and reasoning in both Math and Reading & Writing by reducing careless errors and reinforcing second-tier skills. Demonstrate measurable progress in linear functions, lines and angles, rhetorical synthesis, and command of evidence. Achieve consistent timing improvements under moderate pressure while maintaining persistence. Track and celebrate incremental score gains and error reduction to sustain motivation and build confidence."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Linear functions. 2. Lines, angles, and triangles. 3. Linear equations in one variable. 4. Linear inequalities in one or two variables. 5. Equivalent expressions."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Rhetorical Synthesis. 2. Command of Evidence - Textual. 3. Transitions."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Linear functions": "Engage in daily targeted problem sets focusing on interpreting and manipulating linear functions under timed conditions. Track accuracy and time per problem to visualize progress weekly. Reflect on errors to identify patterns and adjust strategies accordingly, discussing insights with a mentor or peer to reinforce learning.",
#           "Lines, angles, and triangles": "Practice geometry problems emphasizing precision and conceptual understanding. Use visual aids and diagrams to deepen comprehension. Incorporate weekly mixed sets to build cognitive flexibility and review mistakes with a focus on reducing careless slips.",
#           "Linear equations in one variable": "Solve progressively challenging equations daily, increasing complexity and time constraints. Maintain a log of recurring errors and adapt methods when progress plateaus. Share reflections with a study partner to gain perspective and encouragement.",
#           "Linear inequalities in one or two variables": "Work on interpreting and solving inequalities with varied formats. Use timed drills to build speed and accuracy. Celebrate milestones such as streaks of error-free problems to sustain motivation.",
#           "Equivalent expressions": "Regularly practice simplifying and transforming expressions, focusing on recognizing patterns quickly. Use weekly summaries to chart improvement and adjust practice intensity based on performance trends."
#         },
#         "Reading and Writing": {
#           "Rhetorical Synthesis": "Analyze complex passages daily, focusing on integrating multiple sources and viewpoints. Use timed practice to simulate test conditions. Maintain a journal of synthesis strategies that work and areas needing adjustment, reviewing these weekly with a mentor.",
#           "Command of Evidence - Textual": "Practice identifying and justifying evidence in diverse texts. Use targeted drills with immediate feedback to reduce errors. Track progress visually and reflect on which question types cause hesitation, adapting approaches as needed.",
#           "Transitions": "Engage in exercises that require selecting and evaluating transitions within passages. Incorporate peer review sessions to gain external perspectives and reinforce learning. Celebrate improvements publicly to counter feelings of being unseen."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Monday through Thursday focus on paired skill practice, starting the week with weakest skills such as rhetorical synthesis and linear functions, progressing midweek to lines and angles and command of evidence. Fridays are dedicated to comprehensive review of the week's work, analyzing errors and adapting strategies. Saturdays involve timed full-length practice tests followed by detailed review sessions to identify patterns and reinforce accuracy. Sundays serve as a Flex Day for rest, reflection, and adaptive activities."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Use this day for low-pressure reflection on errors and progress, journaling insights and adjustments. Experiment with new study tools or alternate problem-solving techniques to foster adaptability. Engage in mixed-skill challenges that blend math and reading tasks to enhance cognitive flexibility. Incorporate mindfulness or physical activities to recharge focus and resilience. Set clear, achievable goals for the upcoming week, celebrating small wins to maintain motivation and counter discouragement."
#     }
#   ]
# }
# Response: {
#   "title": "Peak Phase",
#   "description": [
#     {
#       "title": "Weekly Goals",
#       "description": "Each week, aim to improve accuracy and reasoning in prioritized Math and Reading & Writing skills by at least 5%. Reduce repeat mistakes through targeted review and reflection. Strengthen endurance by completing at least one full-length timed test weekly with consistent pacing. Enhance confidence under pressure by stabilizing score variance within a 20-point range. Demonstrate adaptability by adjusting at least one practice strategy weekly based on reflection prompts and feedback."
#     },
#     {
#       "title": "Skill Areas",
#       "description": [
#         {
#           "title": "Math",
#           "description": "1. Area and volume. 2. One-variable data: Distributions and measures of center and spread. 3. Right triangles and trigonometry. 4. Ratios, rates, proportional relationships, and units."
#         },
#         {
#           "title": "Reading & Writing",
#           "description": "1. Command of Evidence - Quantitative. 2. Text Structure and Purpose. 3. Central Ideas and Details. 4. Inferences. 5. Cross-text Connections."
#         }
#       ]
#     },
#     {
#       "title": "Practice Methods",
#       "description": {
#         "Math": {
#           "Area and volume": "Daily targeted problem sets focusing on varied shapes and real-world applications. Track accuracy and time per problem to visualize progress weekly. Reflect on errors to identify patterns and adjust problem-solving approaches.",
#           "One-variable data: Distributions and measures of center and spread": "Weekly data interpretation exercises with increasing complexity. Use charts to monitor improvement and discuss findings with a mentor or peer to gain new perspectives.",
#           "Right triangles and trigonometry": "Consistent practice of right triangle problems emphasizing conceptual understanding and formula application. Incorporate timed drills to build endurance and confidence under pressure.",
#           "Ratios, rates, proportional relationships, and units": "Integrate mixed problem sets twice weekly, focusing on real-life contexts. Use reflection prompts to evaluate strategy effectiveness and adapt methods as needed."
#         },
#         "Reading and Writing": {
#           "Command of Evidence - Quantitative": "Daily practice identifying and interpreting quantitative evidence in passages. Chart weekly accuracy and review mistakes with a peer or mentor to reinforce learning and maintain motivation.",
#           "Text Structure and Purpose": "Analyze diverse passage types twice weekly, focusing on author intent and organizational patterns. Use visual summaries to track understanding and adjust reading strategies accordingly.",
#           "Central Ideas and Details": "Practice extracting main ideas and supporting details through targeted exercises. Reflect weekly on progress and tweak note-taking or annotation methods to enhance retention.",
#           "Inferences": "Engage in inference-based questions daily, emphasizing reasoning and justification. Share insights with a study partner to deepen understanding and maintain engagement.",
#           "Cross-text Connections": "Weekly paired passage exercises focusing on synthesis and comparison. Use reflection prompts to assess strategy effectiveness and remain flexible in approach."
#         }
#       }
#     },
#     {
#       "title": "Weekly Structure",
#       "description": "Monday through Thursday, focus on dual-skill practice pairing one Math and one Reading & Writing skill, starting with weakest areas early in the week and progressing to moderate skills midweek. Fridays are dedicated to comprehensive review of errors and strategy adjustments. Saturdays involve full-length timed practice tests simulating real test conditions, followed by detailed review sessions. Sundays serve as a Flex Day for rest, reflection, and adaptive activities."
#     },
#     {
#       "title": "Flex Day Activities",
#       "description": "Use this day for low-pressure reflection on the week's progress, reviewing error logs and celebrating small wins both privately and with a mentor or peer. Experiment with new study tools or alternate problem-solving techniques to foster adaptability. Engage in mixed-skill challenges that encourage pattern recognition without time pressure. Incorporate mindfulness or light physical activity to recharge mentally and emotionally. Set clear, personalized goals for the upcoming week to maintain intrinsic motivation and a strong sense of purpose."
#     }
#   ]
# }
# Folders Progress: 100%|██████████| 3/3 [03:03<00:00, 61.23s/it]
# Response: {
#     "Tips to Make It Work Best": [
#         "After each practice session, create a simple visual chart tracking your accuracy and time per section to clearly see progress and identify patterns that need adjustment.",
#         "Incorporate weekly reflection prompts asking what strategies worked and which didn’t, then deliberately tweak one approach to test its impact before the next session.",
#         "Alternate between timed drills focused on speed and untimed practice emphasizing accuracy to build flexibility in pacing and decision-making under pressure.",
#         "Log your confidence level immediately after each practice test or section to monitor emotional shifts and address dips proactively with targeted mindset strategies.",
#         "Engage in peer-based, time-boxed simulations where you can compare approaches and receive feedback, helping you break habitual methods and gain fresh perspectives."
#     ],
#     "Words of Encouragement": "Your steady commitment and resilience are your greatest assets on this journey. Remember, progress in complex challenges like the SAT rarely shows up overnight, but your consistent effort is quietly building a foundation that will support your breakthrough. It’s natural to feel unseen at times, but your persistence is not unnoticed—it’s the quiet force that moves you forward. Embrace adaptability as a tool to sharpen your efforts, not as a sign of weakness. Each small milestone you reach is a testament to your growth and purpose. Keep trusting the process, lean on your support network, and know that your dedication is steadily bringing you closer to your goal. The long journey you’re on is worthwhile, and your quiet strength will carry you through to success."
# }
