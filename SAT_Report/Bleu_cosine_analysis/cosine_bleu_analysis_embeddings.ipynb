# %%
import os, json, re
from itertools import combinations
from sklearn.metrics.pairwise import cosine_similarity
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import pandas as pd
import openai
from dotenv import load_dotenv
from sklearn.feature_extraction.text import TfidfVectorizer

load_dotenv()
# Out:
# True

# %%
common_words_path=r"C:\Users\Manideep S\Downloads\L@\SAT Readiness Report\common_words.txt"

# %%
def extract_common_words(common_words_path: str) -> list:
    with open(common_words_path, 'r') as f:
        return [line.strip().lower() for line in f if line.strip()]

# %%
def flatten_description(desc) -> str:
    if isinstance(desc, str):
        return desc
    elif isinstance(desc, list):
        return ' '.join(flatten_description(item) for item in desc)
    elif isinstance(desc, dict):
        return ' '.join(f"{k} {flatten_description(v)}" for k, v in desc.items())
    else:
        return str(desc)

# %%
def clean_text(text) -> str:
    text = flatten_description(text)
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
def extract_common_words(common_words_path: str) -> list:
    with open(common_words_path, 'r') as f:
        return [line.strip().lower() for line in f if line.strip()]

# %%
def get_embedding(text: str, model: str = "text-embedding-3-small") -> list:
    response = openai.embeddings.create(model=model, input=text)
    return response.data[0].embedding

# %%
def compute_cosine_from_embeddings(e1, e2) -> float:
    return cosine_similarity([e1], [e2])[0][0]

# %%
def flatten(content):
        if isinstance(content, str):
            return content
        elif isinstance(content, list):
            return " ".join(flatten(item) for item in content)
        elif isinstance(content, dict):
            return " ".join(flatten(v) for v in content.values())
        return ""

# %% [markdown]
# ## Code

# %%
def extract_sections_with_weekly_schedule(data):
    sections = {}

    for section in data:
        title = section.get("title")
        desc = section.get("description")
        if title == "Your Study Plan: Based on You" and isinstance(desc, list):
            for subsection in desc:
                sub_title = subsection.get("title")
                sub_desc = subsection.get("description")
                if sub_title == "Study Plan Phases" and isinstance(sub_desc, list):
                    for sub2_section in sub_desc:
                        sub2_title = sub2_section.get("title")
                        sub2_desc = sub2_section.get("description")
                        sections[sub2_title] = flatten(sub2_desc)
                else:
                    sections[sub_title] = flatten(sub_desc)
        else:
            sections[title] = flatten(desc)
    return sections

# %%
def compute_bleu_openai_cosine_scores(folder_path: str):
    files = [f for f in os.listdir(folder_path) if re.match(r'.*_\d+\.json$', f)]
    if len(files) < 2:
        raise ValueError("Need at least two `.json` files to compare.")

    all_data = {}
    for file in files:
        with open(os.path.join(folder_path, file), 'r', encoding='utf-8') as f:
            json_data = json.load(f)

        extracted = extract_sections_with_weekly_schedule(json_data)
        cleaned = {k: clean_text(v) for k, v in extracted.items()}
        all_data[file] = cleaned

    all_sections = sorted({title for d in all_data.values() for title in d.keys()})
    smoothing = SmoothingFunction().method1
    rows = []

    for f1, f2 in combinations(files, 2):
        row = {'doc1': f1, 'doc2': f2}
        full1, full2 = [], []

        for section in all_sections:
            t1 = all_data[f1].get(section, "")
            t2 = all_data[f2].get(section, "")
            common_words = set(extract_common_words(common_words_path=common_words_path))
            t1 = " ".join([w for w in t1.split() if w not in common_words])
            t2 = " ".join([w for w in t2.split() if w not in common_words])

            print("\n\nSection:", section)
            print("Text1:", t1)
            print("Text2:", t2)

            full1.append(t1)
            full2.append(t2)

            bleu = sentence_bleu([t1.split()], t2.split(), smoothing_function=smoothing)
            row[f"{section}_BLEU"] = round(bleu, 4)

            e1 = get_embedding(t1)
            e2 = get_embedding(t2)
            cos = compute_cosine_from_embeddings(e1, e2)
            row[f"{section}_Cosine"] = round(cos, 4)

        joined1 = " ".join(full1)
        joined2 = " ".join(full2)

        bleu_full = sentence_bleu([joined1.split()], joined2.split(), smoothing_function=smoothing)
        e1_full = get_embedding(joined1)
        e2_full = get_embedding(joined2)
        cos_full = compute_cosine_from_embeddings(e1_full, e2_full)

        row["FULL_TEXT_BLEU"] = round(bleu_full, 4)
        row["FULL_TEXT_Cosine"] = round(cos_full, 4)

        rows.append(row)

    return pd.DataFrame(rows)

# %%
#### Single user example to test the code:

user = "Aarthi"
path = r"C:\Users\Manideep S\Downloads\L@\SAT Readiness Report\Users_data\{user}".format(user=user)
df = pd.DataFrame()

path_user = path
if os.path.isdir(path_user):
    print(f"Processing user folder: {path_user}")
    try:
        results = compute_bleu_openai_cosine_scores(path_user)
        results['User'] = user  # Add a column to track which user's folder it was
        df = pd.concat([df, results], ignore_index=True)
    except Exception as e:
        print(f"Error processing {user}: {e}")

print(df)
# Out:
# Processing user folder: C:\Users\Manideep S\Downloads\L@\SAT Readiness Report\Users_data\Aarthi
#
#
# Section: Elevation
# Text1: date july 1 2025 july 31 2025 reading and writing build fluency in information and ideas through timed practice and reflective summaries to enhance confidence and analytical skills math strengthen algebra skills with peer discussions or stepwise problem solving to refine accuracy and deepen conceptual understanding
# Text2: date july 1 2025 july 31 2025 reading and writing strengthen information and ideas through reflective practice and timed drills that build confidence and fluency math enhance algebra skills with targeted refinement and spaced repetition to solidify accuracy and speed
#
#
# Section: Footer
# Text1: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
# Text2: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
#
#
# Section: Foundation
# Text1: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low pressure exercises that encourage active engagement without disrupting your balance math concentrate on advanced math fundamentals using incremental challenges that respect your steady learning pace and reduce stress
# Text2: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low pressure exercises that encourage gradual engagement with complex text features math concentrate on advanced math fundamentals pacing review to avoid overwhelm while building problem solving stamina
#
#
# Section: Math Strategies
# Text1: 1 target advanced math by working through layered problem sets that gradually increase in difficulty allowing you to stretch without overwhelming your steady approach 2 refine your strong algebra skills by reviewing problem solving steps aloud or with a peer to deepen understanding and reinforce your methodical style 3 sustain confidence in geometry and trigonometry through visual problem mapping and timed drills that fit your preference for clear structure and measurable progress
# Text2: 1 target advanced math by introducing incremental problem difficulty allowing you to stretch your skills without disrupting your inner balance 2 refine your strong algebra skills through timed drills that build fluency while respecting your steady approach to learning 3 sustain confidence in problem solving and data analysis by incorporating step by step visual breakdowns aligning with your reflective and deliberate style
#
#
# Section: Peak
# Text1: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error review in craft and structure to solidify readiness math sharpen speed and precision in geometry and trigonometry with targeted drills and full length practice tests to ensure consistency under pressure
# Text2: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error analysis in craft and structure to close remaining gaps math sharpen speed and accuracy in advanced math and problem solving with personalized timed practice and review
#
#
# Section: Reading Writing Strategies
# Text1: 1 focus on craft and structure by breaking down complex sentence relationships in short manageable sessions to gently expand your analytical comfort zone 2 reinforce your strength in information and ideas by reflecting on passage arguments and summarizing key points to build confidence through active engagement 3 maintain momentum in standard english conventions by using gamified quizzes that reward accuracy and speed aligning with your preference for steady enjoyable progress
# Text2: 1 focus on craft and structure by gradually engaging with more complex sentence and paragraph relationships framing this as a manageable challenge rather than pressure 2 reinforce your strengths in information and ideas by reflecting on passage arguments and evidence using your natural thoughtfulness to deepen understanding 3 maintain momentum in standard english conventions through gamified exercises that reward accuracy and consistency supporting your preference for steady progress
#
#
# Section: Sample Weekly Schedule
# Text1: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area standard english conventions duration 60 minutes saturday focus area mixed subject drill with emphasis on timing and accuracy duration 60 minutes sunday focus area flex day for review or rest duration 30 minutes
# Text2: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area expression of ideas duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
#
#
# Section: Study Tips
# Text1: 1 let s build skill in craft and structure by breaking down sentence relationships in short focused sessions that fit your steady approach 2 try focusing on advanced math with incremental problem sets that encourage gradual growth without disrupting your balance 3 you can boost confidence in information and ideas by summarizing passage arguments to deepen engagement and reflection 4 establish a consistent weekly routine that balances study with mental rest aligning with your preference for sustainable progress toward your august test date 5 recognize that small deliberate challenges are the path to growth pacing yourself thoughtfully will help you move beyond comfort zones without losing stability
# Text2: 1 let s build skill in craft and structure by breaking down complex sentence relationships into smaller parts which fits your steady learning style 2 try focusing on advanced math with incremental problem difficulty to gently push your boundaries without disrupting your balance 3 you can boost confidence in information and ideas by reflecting on passage arguments leveraging your natural thoughtfulness 4 establish a consistent weekly routine that balances focused study sessions with breaks supporting your preference for sustainable progress as the test date approaches 5 recognize that occasional discomfort in tackling harder problems is a sign of growth not loss of balance and can lead to meaningful improvement
#
#
# Section: Summary
# Text1: your persistent hiker mindset equips you with patience and emotional steadiness which are assets in a long term sat journey you excel in maintaining consistency and avoiding burnout but your preference for comfort can slow progress in more demanding areas recognizing when to introduce micro challenges will be key to moving past plateaus while preserving your balance
# Text2: your persistent hiker mindset favors steady balanced progress and emotional stability which supports consistent sat preparation your strengths in math accuracy and thoughtful reading comprehension reflect this approach the challenge lies in embracing moments of productive discomfort to overcome plateaus especially in areas that require more active struggle aligning your study plan with your preference for sustainable growth will help maintain motivation and avoid burnout
#
#
# Section: Want to Go Further?
# Text1: aarthi your steady and thoughtful approach has built a strong foundation in both reading writing and math embracing targeted challenges in specific domains will help you close the gap to your goal score while maintaining your balance sherpal offers personalized insights and adaptive coaching designed to support your growth with clarity and precision guiding you through each step toward your best performance
# Text2: aarthi your steady approach and strong accuracy reflect a clear understanding of your strengths and limits embracing targeted challenges will help you bridge the gap to your goal score while maintaining your preferred balance sherpal offers personalized insights and adaptive coaching designed to support your growth with clarity and precision guiding you through each step of your preparation
#
#
# Section: What This Means For You
# Text1: your persistent hiker mindset supports steady progress and emotional balance but may limit how often you push beyond comfort which can affect peak performance academic strengths your high accuracy in information and ideas and standard english conventions aligns with your thoughtful and deliberate approach while your near perfect scores in algebra and problem solving reflect your calm precision and consistency growth areas craft and structure in reading writing is your lowest domain representing an opportunity to engage more actively with complex texts which fits with your challenge of embracing stretch goals in math advanced math shows room for refinement suggesting a chance to deepen understanding without disrupting your steady pace closing insight your goal score is within reach if you balance your natural persistence with targeted challenges that encourage growth
# Text2: your persistent hiker mindset supports your strength in maintaining high accuracy and steady progress though it may also lead to avoiding the discomfort of pushing harder academically your reading writing strength lies in information and ideas and standard english conventions reflecting your thoughtful and balanced approach to comprehension and language in math your strengths in algebra and problem solving align with your methodical and calm problem solving style growth areas include craft and structure in reading writing where deeper engagement with complex texts can expand your skills and advanced math where embracing more challenging problems will enhance your readiness improving these areas will require stepping beyond comfort zones in a controlled way consistent with your growth strategy your goal score is within reach if you continue to build on your strengths while gradually addressing these targeted challenges
#
#
# Section: Your Learning Persona
# Text1: hello aarthi as a persistent hiker you approach your sat preparation with steady determination and a clear focus on maintaining balance your calm and thoughtful nature helps you manage stress effectively allowing for consistent progress without burnout you naturally prioritize emotional well being alongside academic goals which supports sustainable growth at times you may lean toward comfort zones and avoid pushing into more challenging areas which can slow advancement embracing small manageable challenges will help you stretch your abilities while preserving your sense of harmony
# Text2: hello aarthi as a persistent hiker you approach your sat preparation with steady determination and a clear focus on maintaining balance your calm and thoughtful nature helps you manage stress effectively allowing for consistent progress without burnout you naturally prioritize emotional well being alongside academic goals which supports sustainable growth at times you may lean toward comfort zones and avoid challenges that disrupt your inner harmony which can slow advancement embracing small manageable challenges will help you stretch your abilities while preserving your preferred steady pace
#
#
# Section: Your SAT Practice Snapshot
# Text1: your current sat practice shows strong performance with a reading writing score of 730 and a math score of 790 combining for a total of 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal score set at 1550 your efforts are well aligned with your target indicating that focused refinement can close the gap effectively
# Text2: your current sat practice shows strong performance with a reading writing score of 730 and a math score of 790 combining for a total of 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal set at 1550 your efforts are well aligned with steady improvement indicating that focused adjustments can bring you closer to your target
#
#
# Section: Elevation
# Text1: date july 1 2025 july 31 2025 reading and writing build fluency in information and ideas through timed practice and reflective summaries to enhance confidence and analytical skills math strengthen algebra skills with peer discussions or stepwise problem solving to refine accuracy and deepen conceptual understanding
# Text2: date july 1 2025 july 31 2025 reading and writing strengthen information and ideas through reflective exercises and timed drills that leverage your analytical strengths and promote confidence math enhance algebra skills with targeted problem variations and spaced repetition to solidify fluency and accuracy
#
#
# Section: Footer
# Text1: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
# Text2: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
#
#
# Section: Foundation
# Text1: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low pressure exercises that encourage active engagement without disrupting your balance math concentrate on advanced math fundamentals using incremental challenges that respect your steady learning pace and reduce stress
# Text2: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with low pressure segmented practice to build comfort with complex sentence analysis while maintaining emotional balance math focus on advanced math fundamentals using paced review sessions that encourage steady progress without triggering stress
#
#
# Section: Math Strategies
# Text1: 1 target advanced math by working through layered problem sets that gradually increase in difficulty allowing you to stretch without overwhelming your steady approach 2 refine your strong algebra skills by reviewing problem solving steps aloud or with a peer to deepen understanding and reinforce your methodical style 3 sustain confidence in geometry and trigonometry through visual problem mapping and timed drills that fit your preference for clear structure and measurable progress
# Text2: 1 address advanced math by tackling one concept at a time through guided problem sets that encourage gradual stretching beyond comfort zones without pressure 2 refine your strong algebra skills by reviewing problem variations and timing yourself to build fluency while preserving your calm focus 3 sustain confidence in problem solving and data analysis by incorporating visual aids and step by step reasoning to reinforce your methodical strengths
#
#
# Section: Peak
# Text1: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error review in craft and structure to solidify readiness math sharpen speed and precision in geometry and trigonometry with targeted drills and full length practice tests to ensure consistency under pressure
# Text2: date august 1 2025 august 8 2025 reading and writing focus on timed practice of all domains emphasizing error patterns in craft and structure to sharpen precision under test conditions math refine speed and accuracy in advanced math and problem solving through full length simulations and strategic review
#
#
# Section: Reading Writing Strategies
# Text1: 1 focus on craft and structure by breaking down complex sentence relationships in short manageable sessions to gently expand your analytical comfort zone 2 reinforce your strength in information and ideas by reflecting on passage arguments and summarizing key points to build confidence through active engagement 3 maintain momentum in standard english conventions by using gamified quizzes that reward accuracy and speed aligning with your preference for steady enjoyable progress
# Text2: 1 focus on craft and structure by breaking down complex sentence relationships into smaller parts allowing you to engage with challenging content without overwhelming your balance 2 reinforce your strengths in information and ideas by reflecting on passage logic and practicing paraphrasing to deepen comprehension and confidence 3 maintain momentum in standard english conventions by gamifying grammar drills rewarding yourself for accuracy to keep motivation aligned with your steady approach
#
#
# Section: Sample Weekly Schedule
# Text1: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area standard english conventions duration 60 minutes saturday focus area mixed subject drill with emphasis on timing and accuracy duration 60 minutes sunday focus area flex day for review or rest duration 30 minutes
# Text2: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area expression of ideas duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
#
#
# Section: Study Tips
# Text1: 1 let s build skill in craft and structure by breaking down sentence relationships in short focused sessions that fit your steady approach 2 try focusing on advanced math with incremental problem sets that encourage gradual growth without disrupting your balance 3 you can boost confidence in information and ideas by summarizing passage arguments to deepen engagement and reflection 4 establish a consistent weekly routine that balances study with mental rest aligning with your preference for sustainable progress toward your august test date 5 recognize that small deliberate challenges are the path to growth pacing yourself thoughtfully will help you move beyond comfort zones without losing stability
# Text2: 1 let s build skill in craft and structure by breaking down complex sentences into manageable parts which fits your steady and thoughtful approach 2 try focusing on advanced math concepts with paced stepwise practice that respects your preference for gradual growth 3 you can boost confidence in information and ideas by reflecting on passage logic and paraphrasing key points to deepen understanding 4 establish a calm consistent study routine that balances focused work with breaks supporting your emotional stability as you prepare for the august test date 5 embrace small challenges as opportunities to grow your skills without disrupting your inner balance recognizing that progress often comes from deliberate incremental steps
#
#
# Section: Summary
# Text1: your persistent hiker mindset equips you with patience and emotional steadiness which are assets in a long term sat journey you excel in maintaining consistency and avoiding burnout but your preference for comfort can slow progress in more demanding areas recognizing when to introduce micro challenges will be key to moving past plateaus while preserving your balance
# Text2: your persistent hiker mindset favors steady stress free progress which has helped you build a strong foundation in both reading writing and math you excel in maintaining accuracy and thoughtful analysis but tend to avoid intense pressure or rapid shifts in difficulty balancing your natural calm with small purposeful challenges will be key to moving beyond current plateaus and reaching your goal
#
#
# Section: Want to Go Further?
# Text1: aarthi your steady and thoughtful approach has built a strong foundation in both reading writing and math embracing targeted challenges in specific domains will help you close the gap to your goal score while maintaining your balance sherpal offers personalized insights and adaptive coaching designed to support your growth with clarity and precision guiding you through each step toward your best performance
# Text2: aarthi your steady and thoughtful approach has built a strong foundation in both reading writing and math facing targeted challenges in craft and structure and advanced math will help you close the gap to your goal score sherpal offers personalized insights and adaptive coaching designed to support your balanced growth and keep you on track with clear progress markers
#
#
# Section: What This Means For You
# Text1: your persistent hiker mindset supports steady progress and emotional balance but may limit how often you push beyond comfort which can affect peak performance academic strengths your high accuracy in information and ideas and standard english conventions aligns with your thoughtful and deliberate approach while your near perfect scores in algebra and problem solving reflect your calm precision and consistency growth areas craft and structure in reading writing is your lowest domain representing an opportunity to engage more actively with complex texts which fits with your challenge of embracing stretch goals in math advanced math shows room for refinement suggesting a chance to deepen understanding without disrupting your steady pace closing insight your goal score is within reach if you balance your natural persistence with targeted challenges that encourage growth
# Text2: your persistent hiker mindset supports your calm and balanced approach which strengthens your consistency but may limit pushing into more demanding challenges academic strengths your high accuracy in information and ideas and standard english conventions aligns with your thoughtful learning style while your near perfect scores in algebra and problem solving reflect your steady precise work ethic growth areas craft and structure in reading writing is your current focus area improving here will deepen your analytical skills and complement your strengths in math advanced math shows room for refinement and addressing this will help you maintain momentum without disrupting your balance closing insight your goal score is within reach if you continue to apply deliberate effort and embrace incremental challenges
#
#
# Section: Your Learning Persona
# Text1: hello aarthi as a persistent hiker you approach your sat preparation with steady determination and a clear focus on maintaining balance your calm and thoughtful nature helps you manage stress effectively allowing for consistent progress without burnout you naturally prioritize emotional well being alongside academic goals which supports sustainable growth at times you may lean toward comfort zones and avoid pushing into more challenging areas which can slow advancement embracing small manageable challenges will help you stretch your abilities while preserving your sense of harmony
# Text2: hello aarthi as a persistent hiker you approach your sat preparation with steady focus and a clear sense of balance you value emotional stability and sustainable progress which helps you maintain calm under pressure and avoid burnout your thoughtful and deliberate nature supports consistent growth though you may sometimes shy away from challenges that disrupt your inner harmony embracing small manageable challenges can help you stretch your abilities without sacrificing your well being
#
#
# Section: Your SAT Practice Snapshot
# Text1: your current sat practice shows strong performance with a reading writing score of 730 and a math score of 790 combining for a total of 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal score set at 1550 your efforts are well aligned with your target indicating that focused refinement can close the gap effectively
# Text2: your current sat scores show strong performance with a reading writing score of 730 and a math score of 790 totaling 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal set at 1550 your steady effort positions you well to close the gap through targeted refinement
#
#
# Section: Elevation
# Text1: date july 1 2025 july 31 2025 reading and writing build fluency in information and ideas through timed practice and reflective summaries to enhance confidence and analytical skills math strengthen algebra skills with peer discussions or stepwise problem solving to refine accuracy and deepen conceptual understanding
# Text2: date july 1 2025 july 31 2025 reading and writing strengthen information and ideas through reflective summarization and timed practice to build fluency and confidence math enhance algebra skills with collaborative review sessions or peer discussions to deepen understanding and maintain motivation
#
#
# Section: Footer
# Text1: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
# Text2: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
#
#
# Section: Foundation
# Text1: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low pressure exercises that encourage active engagement without disrupting your balance math concentrate on advanced math fundamentals using incremental challenges that respect your steady learning pace and reduce stress
# Text2: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low stress exercises that encourage gradual skill building without overwhelming pressure math concentrate on advanced math fundamentals using paced problem sets that respect your preference for steady progress and avoid burnout
#
#
# Section: Math Strategies
# Text1: 1 target advanced math by working through layered problem sets that gradually increase in difficulty allowing you to stretch without overwhelming your steady approach 2 refine your strong algebra skills by reviewing problem solving steps aloud or with a peer to deepen understanding and reinforce your methodical style 3 sustain confidence in geometry and trigonometry through visual problem mapping and timed drills that fit your preference for clear structure and measurable progress
# Text2: 1 target advanced math by working through progressively challenging problems in small sets allowing you to stretch without disrupting your study balance 2 refine your algebra skills by reviewing problem solving steps aloud or with a peer leveraging your thoughtful nature to solidify understanding 3 sustain confidence in geometry and trigonometry through timed quizzes that simulate test conditions helping you maintain precision under mild pressure
#
#
# Section: Peak
# Text1: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error review in craft and structure to solidify readiness math sharpen speed and precision in geometry and trigonometry with targeted drills and full length practice tests to ensure consistency under pressure
# Text2: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error analysis in craft and structure to close remaining gaps math sharpen speed and accuracy in geometry and trigonometry with full length practice tests that reinforce your strengths under realistic conditions
#
#
# Section: Reading Writing Strategies
# Text1: 1 focus on craft and structure by breaking down complex sentence relationships in short manageable sessions to gently expand your analytical comfort zone 2 reinforce your strength in information and ideas by reflecting on passage arguments and summarizing key points to build confidence through active engagement 3 maintain momentum in standard english conventions by using gamified quizzes that reward accuracy and speed aligning with your preference for steady enjoyable progress
# Text2: 1 focus on craft and structure by breaking down sentence relationships and rhetorical functions in short daily exercises that feel manageable rather than overwhelming 2 reinforce your strength in information and ideas by summarizing passages aloud or in writing to deepen comprehension and build confidence through reflection 3 maintain momentum in standard english conventions by gamifying grammar drills rewarding yourself for accuracy to keep motivation aligned with your steady learning style
#
#
# Section: Sample Weekly Schedule
# Text1: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area standard english conventions duration 60 minutes saturday focus area mixed subject drill with emphasis on timing and accuracy duration 60 minutes sunday focus area flex day for review or rest duration 30 minutes
# Text2: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area standard english conventions duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
#
#
# Section: Study Tips
# Text1: 1 let s build skill in craft and structure by breaking down sentence relationships in short focused sessions that fit your steady approach 2 try focusing on advanced math with incremental problem sets that encourage gradual growth without disrupting your balance 3 you can boost confidence in information and ideas by summarizing passage arguments to deepen engagement and reflection 4 establish a consistent weekly routine that balances study with mental rest aligning with your preference for sustainable progress toward your august test date 5 recognize that small deliberate challenges are the path to growth pacing yourself thoughtfully will help you move beyond comfort zones without losing stability
# Text2: 1 let s build skill in craft and structure by breaking down sentence relationships in short focused sessions that fit your steady pace 2 try focusing on advanced math with small manageable problem sets that encourage gradual growth without disrupting your balance 3 you can boost confidence in information and ideas by summarizing passages aloud to deepen comprehension and reflection 4 establish a consistent weekly routine that balances study with rest aligning with your preference for sustainable progress as your test date approaches 5 embrace challenges as opportunities to expand your skills gently recognizing that pushing boundaries can coexist with maintaining your inner calm
#
#
# Section: Summary
# Text1: your persistent hiker mindset equips you with patience and emotional steadiness which are assets in a long term sat journey you excel in maintaining consistency and avoiding burnout but your preference for comfort can slow progress in more demanding areas recognizing when to introduce micro challenges will be key to moving past plateaus while preserving your balance
# Text2: your persistent hiker persona favors consistent balanced study habits that protect your well being while advancing your skills this steady approach has yielded strong math results and solid reading performance the main challenge lies in engaging more actively with areas that require deliberate struggle especially in reading writing your study plan will respect your preference for harmony while introducing manageable challenges to foster growth
#
#
# Section: Want to Go Further?
# Text1: aarthi your steady and thoughtful approach has built a strong foundation in both reading writing and math embracing targeted challenges in specific domains will help you close the gap to your goal score while maintaining your balance sherpal offers personalized insights and adaptive coaching designed to support your growth with clarity and precision guiding you through each step toward your best performance
# Text2: aarthi your steady approach and thoughtful preparation have built a strong foundation in both reading writing and math to reach your goal embracing targeted challenges will help you move beyond comfort zones while preserving your balance sherpal offers personalized insights and adaptive coaching designed to support your unique learning style and guide you through each step toward your target score
#
#
# Section: What This Means For You
# Text1: your persistent hiker mindset supports steady progress and emotional balance but may limit how often you push beyond comfort which can affect peak performance academic strengths your high accuracy in information and ideas and standard english conventions aligns with your thoughtful and deliberate approach while your near perfect scores in algebra and problem solving reflect your calm precision and consistency growth areas craft and structure in reading writing is your lowest domain representing an opportunity to engage more actively with complex texts which fits with your challenge of embracing stretch goals in math advanced math shows room for refinement suggesting a chance to deepen understanding without disrupting your steady pace closing insight your goal score is within reach if you balance your natural persistence with targeted challenges that encourage growth
# Text2: your persistent hiker mindset supports steady progress and emotional balance but may limit how often you engage with more demanding challenges academic strengths your high accuracy in information and ideas and standard english conventions reflects your thoughtful and deliberate approach while your near perfect scores in algebra and geometry show strong command and consistency in math growth areas craft and structure in reading writing is your lowest domain representing an opportunity to deepen analytical skills that complement your calm study style advanced math while strong offers room to refine complex problem solving under pressure aligning with your need to gently push beyond comfort closing insight your goal score is within reach if you continue to balance steady effort with targeted challenges that expand your current skill set
#
#
# Section: Your Learning Persona
# Text1: hello aarthi as a persistent hiker you approach your sat preparation with steady determination and a clear focus on maintaining balance your calm and thoughtful nature helps you manage stress effectively allowing for consistent progress without burnout you naturally prioritize emotional well being alongside academic goals which supports sustainable growth at times you may lean toward comfort zones and avoid pushing into more challenging areas which can slow advancement embracing small manageable challenges will help you stretch your abilities while preserving your sense of harmony
# Text2: hello aarthi as a persistent hiker you approach your sat preparation with steady determination and a clear focus on maintaining balance your calm and thoughtful nature helps you manage stress effectively allowing for consistent progress without burnout you naturally prioritize emotional well being alongside academic goals which supports sustainable growth at times you may avoid pushing into uncomfortable challenges which can slow advancement embracing small manageable challenges will help you stretch your abilities while preserving your sense of harmony
#
#
# Section: Your SAT Practice Snapshot
# Text1: your current sat practice shows strong performance with a reading writing score of 730 and a math score of 790 combining for a total of 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal score set at 1550 your efforts are well aligned with your target indicating that focused refinement can close the gap effectively
# Text2: your current sat practice shows strong performance with a reading writing score of 730 and a math score of 790 totaling 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal set at 1550 your efforts are well aligned with steady improvement indicating that focused adjustments can bring you closer to your target
#
#
# Section: Elevation
# Text1: date july 1 2025 july 31 2025 reading and writing strengthen information and ideas through reflective practice and timed drills that build confidence and fluency math enhance algebra skills with targeted refinement and spaced repetition to solidify accuracy and speed
# Text2: date july 1 2025 july 31 2025 reading and writing strengthen information and ideas through reflective exercises and timed drills that leverage your analytical strengths and promote confidence math enhance algebra skills with targeted problem variations and spaced repetition to solidify fluency and accuracy
#
#
# Section: Footer
# Text1: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
# Text2: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
#
#
# Section: Foundation
# Text1: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low pressure exercises that encourage gradual engagement with complex text features math concentrate on advanced math fundamentals pacing review to avoid overwhelm while building problem solving stamina
# Text2: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with low pressure segmented practice to build comfort with complex sentence analysis while maintaining emotional balance math focus on advanced math fundamentals using paced review sessions that encourage steady progress without triggering stress
#
#
# Section: Math Strategies
# Text1: 1 target advanced math by introducing incremental problem difficulty allowing you to stretch your skills without disrupting your inner balance 2 refine your strong algebra skills through timed drills that build fluency while respecting your steady approach to learning 3 sustain confidence in problem solving and data analysis by incorporating step by step visual breakdowns aligning with your reflective and deliberate style
# Text2: 1 address advanced math by tackling one concept at a time through guided problem sets that encourage gradual stretching beyond comfort zones without pressure 2 refine your strong algebra skills by reviewing problem variations and timing yourself to build fluency while preserving your calm focus 3 sustain confidence in problem solving and data analysis by incorporating visual aids and step by step reasoning to reinforce your methodical strengths
#
#
# Section: Peak
# Text1: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error analysis in craft and structure to close remaining gaps math sharpen speed and accuracy in advanced math and problem solving with personalized timed practice and review
# Text2: date august 1 2025 august 8 2025 reading and writing focus on timed practice of all domains emphasizing error patterns in craft and structure to sharpen precision under test conditions math refine speed and accuracy in advanced math and problem solving through full length simulations and strategic review
#
#
# Section: Reading Writing Strategies
# Text1: 1 focus on craft and structure by gradually engaging with more complex sentence and paragraph relationships framing this as a manageable challenge rather than pressure 2 reinforce your strengths in information and ideas by reflecting on passage arguments and evidence using your natural thoughtfulness to deepen understanding 3 maintain momentum in standard english conventions through gamified exercises that reward accuracy and consistency supporting your preference for steady progress
# Text2: 1 focus on craft and structure by breaking down complex sentence relationships into smaller parts allowing you to engage with challenging content without overwhelming your balance 2 reinforce your strengths in information and ideas by reflecting on passage logic and practicing paraphrasing to deepen comprehension and confidence 3 maintain momentum in standard english conventions by gamifying grammar drills rewarding yourself for accuracy to keep motivation aligned with your steady approach
#
#
# Section: Sample Weekly Schedule
# Text1: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area expression of ideas duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
# Text2: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area expression of ideas duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
#
#
# Section: Study Tips
# Text1: 1 let s build skill in craft and structure by breaking down complex sentence relationships into smaller parts which fits your steady learning style 2 try focusing on advanced math with incremental problem difficulty to gently push your boundaries without disrupting your balance 3 you can boost confidence in information and ideas by reflecting on passage arguments leveraging your natural thoughtfulness 4 establish a consistent weekly routine that balances focused study sessions with breaks supporting your preference for sustainable progress as the test date approaches 5 recognize that occasional discomfort in tackling harder problems is a sign of growth not loss of balance and can lead to meaningful improvement
# Text2: 1 let s build skill in craft and structure by breaking down complex sentences into manageable parts which fits your steady and thoughtful approach 2 try focusing on advanced math concepts with paced stepwise practice that respects your preference for gradual growth 3 you can boost confidence in information and ideas by reflecting on passage logic and paraphrasing key points to deepen understanding 4 establish a calm consistent study routine that balances focused work with breaks supporting your emotional stability as you prepare for the august test date 5 embrace small challenges as opportunities to grow your skills without disrupting your inner balance recognizing that progress often comes from deliberate incremental steps
#
#
# Section: Summary
# ...
#
#
# Section: Footer
# Text1: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
# Text2: safe harbor the scores assessments and recommendations provided in this report are for informational purposes only and do not constitute professional educational psychological or legal advice current performance is not necessarily indicative of actual or future results as test day conditions and individual circumstances may vary while care has been taken in the preparation of this material we make no representations or warranties of any kind express or implied about the completeness accuracy or reliability of the information presented any reliance you place on such information is strictly at your own risk we accept no liability for any loss or damage arising from the use of this report 2025 sthirah inc confidential proprietary for internal use only
#
#
# Section: Foundation
# Text1: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with low pressure segmented practice to build comfort with complex sentence analysis while maintaining emotional balance math focus on advanced math fundamentals using paced review sessions that encourage steady progress without triggering stress
# Text2: date may 26 2025 june 30 2025 reading and writing prioritize craft and structure with focused low stress exercises that encourage gradual skill building without overwhelming pressure math concentrate on advanced math fundamentals using paced problem sets that respect your preference for steady progress and avoid burnout
#
#
# Section: Math Strategies
# Text1: 1 address advanced math by tackling one concept at a time through guided problem sets that encourage gradual stretching beyond comfort zones without pressure 2 refine your strong algebra skills by reviewing problem variations and timing yourself to build fluency while preserving your calm focus 3 sustain confidence in problem solving and data analysis by incorporating visual aids and step by step reasoning to reinforce your methodical strengths
# Text2: 1 target advanced math by working through progressively challenging problems in small sets allowing you to stretch without disrupting your study balance 2 refine your algebra skills by reviewing problem solving steps aloud or with a peer leveraging your thoughtful nature to solidify understanding 3 sustain confidence in geometry and trigonometry through timed quizzes that simulate test conditions helping you maintain precision under mild pressure
#
#
# Section: Peak
# Text1: date august 1 2025 august 8 2025 reading and writing focus on timed practice of all domains emphasizing error patterns in craft and structure to sharpen precision under test conditions math refine speed and accuracy in advanced math and problem solving through full length simulations and strategic review
# Text2: date august 1 2025 august 8 2025 reading and writing focus on test simulations emphasizing timing and error analysis in craft and structure to close remaining gaps math sharpen speed and accuracy in geometry and trigonometry with full length practice tests that reinforce your strengths under realistic conditions
#
#
# Section: Reading Writing Strategies
# Text1: 1 focus on craft and structure by breaking down complex sentence relationships into smaller parts allowing you to engage with challenging content without overwhelming your balance 2 reinforce your strengths in information and ideas by reflecting on passage logic and practicing paraphrasing to deepen comprehension and confidence 3 maintain momentum in standard english conventions by gamifying grammar drills rewarding yourself for accuracy to keep motivation aligned with your steady approach
# Text2: 1 focus on craft and structure by breaking down sentence relationships and rhetorical functions in short daily exercises that feel manageable rather than overwhelming 2 reinforce your strength in information and ideas by summarizing passages aloud or in writing to deepen comprehension and build confidence through reflection 3 maintain momentum in standard english conventions by gamifying grammar drills rewarding yourself for accuracy to keep motivation aligned with your steady learning style
#
#
# Section: Sample Weekly Schedule
# Text1: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area expression of ideas duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
# Text2: monday focus area craft and structure duration 60 minutes tuesday focus area advanced math duration 60 minutes wednesday focus area information and ideas duration 60 minutes thursday focus area algebra duration 60 minutes friday focus area standard english conventions duration 60 minutes saturday focus area mixed reading writing review duration 60 minutes sunday focus area flex day duration 30 minutes
#
#
# Section: Study Tips
# Text1: 1 let s build skill in craft and structure by breaking down complex sentences into manageable parts which fits your steady and thoughtful approach 2 try focusing on advanced math concepts with paced stepwise practice that respects your preference for gradual growth 3 you can boost confidence in information and ideas by reflecting on passage logic and paraphrasing key points to deepen understanding 4 establish a calm consistent study routine that balances focused work with breaks supporting your emotional stability as you prepare for the august test date 5 embrace small challenges as opportunities to grow your skills without disrupting your inner balance recognizing that progress often comes from deliberate incremental steps
# Text2: 1 let s build skill in craft and structure by breaking down sentence relationships in short focused sessions that fit your steady pace 2 try focusing on advanced math with small manageable problem sets that encourage gradual growth without disrupting your balance 3 you can boost confidence in information and ideas by summarizing passages aloud to deepen comprehension and reflection 4 establish a consistent weekly routine that balances study with rest aligning with your preference for sustainable progress as your test date approaches 5 embrace challenges as opportunities to expand your skills gently recognizing that pushing boundaries can coexist with maintaining your inner calm
#
#
# Section: Summary
# Text1: your persistent hiker mindset favors steady stress free progress which has helped you build a strong foundation in both reading writing and math you excel in maintaining accuracy and thoughtful analysis but tend to avoid intense pressure or rapid shifts in difficulty balancing your natural calm with small purposeful challenges will be key to moving beyond current plateaus and reaching your goal
# Text2: your persistent hiker persona favors consistent balanced study habits that protect your well being while advancing your skills this steady approach has yielded strong math results and solid reading performance the main challenge lies in engaging more actively with areas that require deliberate struggle especially in reading writing your study plan will respect your preference for harmony while introducing manageable challenges to foster growth
#
#
# Section: Want to Go Further?
# Text1: aarthi your steady and thoughtful approach has built a strong foundation in both reading writing and math facing targeted challenges in craft and structure and advanced math will help you close the gap to your goal score sherpal offers personalized insights and adaptive coaching designed to support your balanced growth and keep you on track with clear progress markers
# Text2: aarthi your steady approach and thoughtful preparation have built a strong foundation in both reading writing and math to reach your goal embracing targeted challenges will help you move beyond comfort zones while preserving your balance sherpal offers personalized insights and adaptive coaching designed to support your unique learning style and guide you through each step toward your target score
#
#
# Section: What This Means For You
# Text1: your persistent hiker mindset supports your calm and balanced approach which strengthens your consistency but may limit pushing into more demanding challenges academic strengths your high accuracy in information and ideas and standard english conventions aligns with your thoughtful learning style while your near perfect scores in algebra and problem solving reflect your steady precise work ethic growth areas craft and structure in reading writing is your current focus area improving here will deepen your analytical skills and complement your strengths in math advanced math shows room for refinement and addressing this will help you maintain momentum without disrupting your balance closing insight your goal score is within reach if you continue to apply deliberate effort and embrace incremental challenges
# Text2: your persistent hiker mindset supports steady progress and emotional balance but may limit how often you engage with more demanding challenges academic strengths your high accuracy in information and ideas and standard english conventions reflects your thoughtful and deliberate approach while your near perfect scores in algebra and geometry show strong command and consistency in math growth areas craft and structure in reading writing is your lowest domain representing an opportunity to deepen analytical skills that complement your calm study style advanced math while strong offers room to refine complex problem solving under pressure aligning with your need to gently push beyond comfort closing insight your goal score is within reach if you continue to balance steady effort with targeted challenges that expand your current skill set
#
#
# Section: Your Learning Persona
# Text1: hello aarthi as a persistent hiker you approach your sat preparation with steady focus and a clear sense of balance you value emotional stability and sustainable progress which helps you maintain calm under pressure and avoid burnout your thoughtful and deliberate nature supports consistent growth though you may sometimes shy away from challenges that disrupt your inner harmony embracing small manageable challenges can help you stretch your abilities without sacrificing your well being
# Text2: hello aarthi as a persistent hiker you approach your sat preparation with steady determination and a clear focus on maintaining balance your calm and thoughtful nature helps you manage stress effectively allowing for consistent progress without burnout you naturally prioritize emotional well being alongside academic goals which supports sustainable growth at times you may avoid pushing into uncomfortable challenges which can slow advancement embracing small manageable challenges will help you stretch your abilities while preserving your sense of harmony
#
#
# Section: Your SAT Practice Snapshot
# Text1: your current sat scores show strong performance with a reading writing score of 730 and a math score of 790 totaling 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal set at 1550 your steady effort positions you well to close the gap through targeted refinement
# Text2: your current sat practice shows strong performance with a reading writing score of 730 and a math score of 790 totaling 1520 your reading accuracy is solid and your math accuracy is notably high reflecting careful and precise work with your goal set at 1550 your efforts are well aligned with steady improvement indicating that focused adjustments can bring you closer to your target
#             doc1           doc2  Elevation_BLEU  Elevation_Cosine  \
# 0  Aarthi_1.json  Aarthi_2.json          0.3282            0.9480
# 1  Aarthi_1.json  Aarthi_3.json          0.3144            0.9356
# 2  Aarthi_1.json  Aarthi_4.json          0.3421            0.9667
# 3  Aarthi_2.json  Aarthi_3.json          0.6009            0.9771
# 4  Aarthi_2.json  Aarthi_4.json          0.4885            0.9568
# 5  Aarthi_3.json  Aarthi_4.json          0.4834            0.9440
#
#    Footer_BLEU  Footer_Cosine  Foundation_BLEU  Foundation_Cosine  \
# 0          1.0            1.0           0.5548             0.9597
# 1          1.0            1.0           0.4225             0.9543
# 2          1.0            1.0           0.5386             0.9676
# 3          1.0            1.0           0.4032             0.9569
# 4          1.0            1.0           0.5063             0.9543
# 5          1.0            1.0           0.4401             0.9496
#
#    Math Strategies_BLEU  Math Strategies_Cosine  ...  \
# 0                0.2464                  0.8970  ...
# 1                0.2151                  0.8570  ...
# 2                0.4008                  0.9383  ...
# 3                0.2892                  0.8598  ...
# 4                0.2052                  0.8869  ...
# 5                0.1378                  0.8411  ...
#
#    Want to Go Further?_Cosine  What This Means For You_BLEU  \
# 0                      0.9402                        0.2463
# 1                      0.9632                        0.4575
# 2                      0.9645                        0.5445
# 3                      0.8963                        0.2620
# 4                      0.9275                        0.2400
# 5                      0.9448                        0.4146
#
#    What This Means For You_Cosine  Your Learning Persona_BLEU  \
# 0                          0.8973                      0.8782
# 1                          0.9538                      0.2814
# 2                          0.9695                      0.8662
# 3                          0.9302                      0.3237
# 4                          0.9117                      0.8110
# 5                          0.9611                      0.3030
#
#    Your Learning Persona_Cosine  Your SAT Practice Snapshot_BLEU  \
# 0                        0.9971                           0.8169
# 1                        0.9759                           0.5835
# 2                        0.9972                           0.7280
# 3                        0.9772                           0.5843
# 4                        0.9948                           0.9014
# 5                        0.9756                           0.6695
#
#    Your SAT Practice Snapshot_Cosine  FULL_TEXT_BLEU  FULL_TEXT_Cosine    User
# 0                             0.9801          0.5790            0.9847  Aarthi
# 1                             0.9513          0.5238            0.9858  Aarthi
# 2                             0.9779          0.6362            0.9878  Aarthi
# 3                             0.9397          0.5325            0.9807  Aarthi
# 4                             0.9983          0.5839            0.9872  Aarthi
# 5                             0.9406          0.5328            0.9860  Aarthi
#
# [6 rows x 31 columns]

# %%
# Define output file path
output_path = os.path.join(path, 'bleu_cosine_results.csv')

# Delete the file if it already exists
if os.path.exists(output_path):
    os.remove(output_path)
    print(f"Deleted existing file: {output_path}")

# Save the new results to CSV
df.to_csv(output_path, index=False)
print(f"Saved results to {output_path}")
# Out:
# Deleted existing file: C:\Users\Manideep S\Downloads\L@\SAT Readiness Report\Users_data\Aarthi\bleu_cosine_results.csv
# Saved results to C:\Users\Manideep S\Downloads\L@\SAT Readiness Report\Users_data\Aarthi\bleu_cosine_results.csv

# %%
import pandas as pd
from IPython.display import display

# Calculate the mean for each column (excluding non-numeric columns)
df_avg = df.select_dtypes(include='number').mean().to_frame().T

# Convert to percentages (multiply by 100)
df_avg_percent = df_avg * 100

# Beautiful print


pd.set_option('display.float_format', '{:,.2f}'.format)
display(df_avg_percent)
# Out:
#    Elevation_BLEU  Elevation_Cosine  Footer_BLEU  Footer_Cosine  \
# 0           42.62             95.47       100.00         100.00
#
#    Foundation_BLEU  Foundation_Cosine  Math Strategies_BLEU  \
# 0            47.76              95.71                 24.91
#
#    Math Strategies_Cosine  Peak_BLEU  Peak_Cosine  ...  \
# 0                   88.00      51.04        94.65  ...
#
#    Want to Go Further?_BLEU  Want to Go Further?_Cosine  \
# 0                     45.63                       93.94
#
#    What This Means For You_BLEU  What This Means For You_Cosine  \
# 0                         36.08                           93.73
#
#    Your Learning Persona_BLEU  Your Learning Persona_Cosine  \
# 0                       57.72                         98.63
#
#    Your SAT Practice Snapshot_BLEU  Your SAT Practice Snapshot_Cosine  \
# 0                            71.39                              96.47
#
#    FULL_TEXT_BLEU  FULL_TEXT_Cosine
# 0           56.47             98.54
#
# [1 rows x 28 columns]

# %%
# Group by 'User' and calculate mean for each user
df_user_avg = df.groupby('User').mean(numeric_only=True)

# Convert to percentages
df_user_avg_percent = df_user_avg * 100

# Calculate overall average for each column
df_overall_avg_percent = df_user_avg_percent.mean().to_frame().T
df_overall_avg_percent.index = ['Overall Average']

# Display user-wise averages and overall average
pd.set_option('display.float_format', '{:,.2f}'.format)
display(df_user_avg_percent)
display(df_overall_avg_percent)
# Out:
#         Elevation_BLEU  Elevation_Cosine  Footer_BLEU  Footer_Cosine  \
# User
# Aarthi           42.62             95.47       100.00         100.00
#
#         Foundation_BLEU  Foundation_Cosine  Math Strategies_BLEU  \
# User
# Aarthi            47.76              95.71                 24.91
#
#         Math Strategies_Cosine  Peak_BLEU  Peak_Cosine  ...  \
# User                                                    ...
# Aarthi                   88.00      51.04        94.65  ...
#
#         Want to Go Further?_BLEU  Want to Go Further?_Cosine  \
# User
# Aarthi                     45.62                       93.94
#
#         What This Means For You_BLEU  What This Means For You_Cosine  \
# User
# Aarthi                         36.08                           93.73
#
#         Your Learning Persona_BLEU  Your Learning Persona_Cosine  \
# User
# Aarthi                       57.72                         98.63
#
#         Your SAT Practice Snapshot_BLEU  Your SAT Practice Snapshot_Cosine  \
# User
# Aarthi                            71.39                              96.46
#
#         FULL_TEXT_BLEU  FULL_TEXT_Cosine
# User
# Aarthi           56.47             98.54
#
# [1 rows x 28 columns]
#                  Elevation_BLEU  Elevation_Cosine  Footer_BLEU  Footer_Cosine  \
# Overall Average           42.62             95.47       100.00         100.00
#
#                  Foundation_BLEU  Foundation_Cosine  Math Strategies_BLEU  \
# Overall Average            47.76              95.71                 24.91
#
#                  Math Strategies_Cosine  Peak_BLEU  Peak_Cosine  ...  \
# Overall Average                   88.00      51.04        94.65  ...
#
#                  Want to Go Further?_BLEU  Want to Go Further?_Cosine  \
# Overall Average                     45.62                       93.94
#
#                  What This Means For You_BLEU  What This Means For You_Cosine  \
# Overall Average                         36.08                           93.73
#
#                  Your Learning Persona_BLEU  Your Learning Persona_Cosine  \
# Overall Average                       57.72                         98.63
#
#                  Your SAT Practice Snapshot_BLEU  \
# Overall Average                            71.39
#
#                  Your SAT Practice Snapshot_Cosine  FULL_TEXT_BLEU  \
# Overall Average                              96.46           56.47
#
#                  FULL_TEXT_Cosine
# Overall Average             98.54
#
# [1 rows x 28 columns]

# %% [markdown]
# # Cosine Similarity checker

# %%
text1 = "Aarthi, as a Persistent Hiker, you bring a calm, balanced approach to your SAT preparation that values steady progress and emotional well-being. Your thoughtful and deliberate mindset helps you maintain harmony in your studies, allowing you to stay resilient even when challenges arise. You naturally prioritize mental health and sustainable growth, which is a powerful strength in managing long-term goals. At times, you might find yourself avoiding intense academic pressure or difficult topics, preferring comfort over stretch, but this awareness is the first step toward embracing growth opportunities. With gentle encouragement to take on micro-challenges, you can continue to build momentum while preserving your inner balance."
text2 = "Aarthi, as a Persistent Hiker, you embody a balanced and thoughtful approach to learning that values steady progress and emotional well-being. Your calm and deliberate mindset helps you maintain harmony in your studies, allowing you to navigate academic challenges with maturity and self-awareness. While you naturally avoid stress and prefer comfort, this same tendency can sometimes hold you back from pushing beyond your limits. Embracing small, manageable challenges will help you grow without disrupting your inner balance, turning moments of discomfort into meaningful steps forward."

# %%
# t1="have you been to the new restaurant in town"
# t2="have you visited the new eatery in the city"
e1 = get_embedding(text1)
e2 = get_embedding(text2)
cos2 = TfidfVectorizer().fit_transform([text1, text2])
print("\n\ncosine:", cosine_similarity(cos2[0:1], cos2[1:2])[0][0])
cos = compute_cosine_from_embeddings(e1, e2)
print("\ncosine:", cos)
# Out:
# cosine: 0.5585502046006118
#
# cosine: 0.9443697862511105
