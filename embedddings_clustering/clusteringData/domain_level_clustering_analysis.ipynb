# %%
import pandas as pd

def read_data(path):
    """
    Reads data from the given file path and returns a DataFrame.

    Parameters:
        path (str): The file path to read the data from.

    Returns:
        pd.DataFrame: The data as a pandas DataFrame.
    """
    try:
        df = pd.read_csv(path)
        return df
    except Exception as e:
        print(f"Error reading the file: {e}")
        return None

# %%
meta_grouping_df = read_data("subject_M_Metadata.csv")
k_4_cluster_df = read_data("subject_M_Kmeans_4.csv")
k_optimal_cluster_df = read_data("subject_M_kmeans_8_optimal_k.csv")

# %%
meta_grouping_df = meta_grouping_df.drop(columns=['vector', 'x', 'y'])

# %%
k_4_cluster_df = k_4_cluster_df.drop(columns=['vector', 'x', 'y'])
k_optimal_cluster_df = k_optimal_cluster_df.drop(columns=['vector', 'x', 'y'])

# %%
meta_grouping_df.describe()
# Out:
#              S.No
# count  388.000000
# mean   194.500000
# std    112.150197
# min      1.000000
# 25%     97.750000
# 50%    194.500000
# 75%    291.250000
# max    388.000000

# %%
meta_grouping_df.head()
# Out:
#    S.No  question_id            prompt_name subject domain skill subskill  \
# 0     1  me_ad07lpni  PID-M-ADM-NLF-EMT-MED       M    ADM   NLF      EMT
# 1     2  me_784m01t5  PID-M-PSD-PER-EMT-EAS       M    PSD   PER      EMT
# 2     3   m_mm69f16h  PID-M-PSD-PCP-EMT-MED       M    PSD   PCP      EMT
# 3     4  me_nj2cdu6j  PID-M-PSD-TVD-EMT-HAR       M    PSD   TVD      EMT
# 4     5  me_0xe0f6v5  PID-M-ALG-LEO-EMT-EAS       M    ALG   LEO      EMT
#
#   difficulty
# 0        MED
# 1        EAS
# 2        MED
# 3        HAR
# 4        EAS

# %%
meta_grouping_df = meta_grouping_df.sort_values(by=['subject', 'domain', 'skill', 'subskill', 'difficulty'])
len(meta_grouping_df)
# Out:
# 388

# %%
# # Merge the two dataframes
# merged_df = meta_grouping_df.merge(
#     k_4_cluster_df,
#     on='question_id',
#     suffixes=('_meta', '_cluster')
# )

# # Find majority domain per cluster
# cluster_domain_map = (
#     merged_df.groupby('cluster')['domain_meta']
#     .agg(lambda x: x.value_counts().index[0])
#     .to_dict()
# )

# # Assign new column: assigned domain
# merged_df['assigned_domain'] = merged_df['cluster'].map(cluster_domain_map)

# # Create a match flag
# merged_df['is_correct'] = merged_df['domain_meta'] == merged_df['assigned_domain']

# # Keep only needed columns
# final_df = merged_df[
#     ['question_id', 'domain_meta', 'domain_cluster', 'cluster', 'assigned_domain', 'is_correct']
# ]

# # Function to color the entire row based on is_correct
# def color_entire_row(row):
#     color = 'background-color: lightgreen' if row['is_correct'] else 'background-color: lightcoral'
#     return [color] * len(row)

# # Split into 4 DataFrames based on cluster
# cluster_dfs = {cluster_id: final_df[final_df['cluster'] == cluster_id] for cluster_id in sorted(final_df['cluster'].unique())}

# # Now style each cluster's dataframe
# styled_cluster_dfs = {
#     cluster_id: df.style.apply(color_entire_row, axis=1)
#     for cluster_id, df in cluster_dfs.items()
# }

# # To display them all in Jupyter
# for cluster_id, styled_df in styled_cluster_dfs.items():
#     display(f"Cluster {cluster_id}")
#     display(styled_df)

# %%
# 1. Merge the two dataframes
merged_df = meta_grouping_df.merge(k_4_cluster_df, on='question_id', suffixes=('_meta', '_cluster'))

# 2. Find majority domain per cluster
cluster_domain_map = (
    merged_df.groupby('cluster')['domain_meta']
    .agg(lambda x: x.value_counts().index[0])
    .to_dict()
)

# 3. Assign new column: assigned domain
merged_df['assigned_domain'] = merged_df['cluster'].map(cluster_domain_map)

# 4. Create a match flag
merged_df['is_correct'] = merged_df['domain_meta'] == merged_df['assigned_domain']

# 5. Visualize - Green if correct, Red if not
def color_row(val):
    return 'background-color: lightgreen' if val else 'background-color: lightcoral'

styled_df = merged_df.style.applymap(color_row, subset=['is_correct'])
# Out:
# C:\Users\Manideep S\AppData\Local\Temp\ipykernel_19520\837601886.py:21: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = merged_df.style.applymap(color_row, subset=['is_correct'])

# %%
styled_df.data.columns
# Out:
# Index(['S.No_meta', 'question_id', 'prompt_name_meta', 'subject_meta',
#        'domain_meta', 'skill_meta', 'subskill_meta', 'difficulty_meta',
#        'S.No_cluster', 'prompt_name_cluster', 'subject_cluster',
#        'domain_cluster', 'skill_cluster', 'subskill_cluster',
#        'difficulty_cluster', 'cluster', 'assigned_domain', 'is_correct'],
#       dtype='object')

# %%
# Select the specified columns
selected_columns = ['question_id', 'domain_meta', 'domain_cluster', 'cluster', 'assigned_domain', 'is_correct']
selected_df = merged_df[selected_columns]

# Apply coloring for the 'is_correct' column
def color_row(val):
    return 'background-color: lightgreen' if val else 'background-color: lightcoral'

styled_selected_df = selected_df.style.applymap(color_row, subset=['is_correct'])

# Display the styled DataFrame
display(styled_selected_df)

# Optionally, write to an HTML file
styled_selected_df.to_html("selected_columns_colored.html", escape=False)
# Out:
# C:\Users\Manideep S\AppData\Local\Temp\ipykernel_19520\2687153596.py:9: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_selected_df = selected_df.style.applymap(color_row, subset=['is_correct'])
# <style type="text/css">
# #T_f1a53_row0_col5, #T_f1a53_row1_col5, #T_f1a53_row2_col5, #T_f1a53_row3_col5, #T_f1a53_row4_col5, #T_f1a53_row5_col5, #T_f1a53_row6_col5, #T_f1a53_row7_col5, #T_f1a53_row8_col5, #T_f1a53_row10_col5, #T_f1a53_row11_col5, #T_f1a53_row12_col5, #T_f1a53_row13_col5, #T_f1a53_row14_col5, #T_f1a53_row15_col5, #T_f1a53_row16_col5, #T_f1a53_row17_col5, #T_f1a53_row18_col5, #T_f1a53_row19_col5, #T_f1a53_row20_col5, #T_f1a53_row21_col5, #T_f1a53_row22_col5, #T_f1a53_row23_col5, #T_f1a53_row24_col5, #T_f1a53_row25_col5, #T_f1a53_row26_col5, #T_f1a53_row28_col5, #T_f1a53_row29_col5, #T_f1a53_row30_col5, #T_f1a53_row31_col5, #T_f1a53_row33_col5, #T_f1a53_row36_col5, #T_f1a53_row37_col5, #T_f1a53_row38_col5, #T_f1a53_row39_col5, #T_f1a53_row40_col5, #T_f1a53_row41_col5, #T_f1a53_row42_col5, #T_f1a53_row43_col5, #T_f1a53_row47_col5, #T_f1a53_row54_col5, #T_f1a53_row55_col5,
# %%
# !pip install itables
# Out:
# Collecting itables
#   Using cached itables-2.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: ipython in d:\anaconda\lib\site-packages (from itables) (8.20.0)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from itables) (1.26.4)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from itables) (2.1.4)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython->itables) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython->itables) (0.18.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from ipython->itables) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda\lib\site-packages (from ipython->itables) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from ipython->itables) (2.15.1)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from ipython->itables) (0.2.0)
# Requirement already satisfied: traitlets>=5 in d:\anaconda\lib\site-packages (from ipython->itables) (5.7.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython->itables) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas->itables) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->itables) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas->itables) (2024.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython->itables) (0.8.3)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->itables) (0.2.5)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas->itables) (1.12.0)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->ipython->itables) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->ipython->itables) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->ipython->itables) (0.2.2)
# Using cached itables-2.3.0-py3-none-any.whl (2.3 MB)
# Installing collected packages: itables
# Successfully installed itables-2.3.0
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import itables
from itables import show

# %%
itables.options.lengthMenu = [ [10, 25, 50, -1], [10, 25, 50, "All"] ]
itables.options.maxBytes = 0  # no size limit
itables.options.columnDefs = [{"targets": "_all", "className": "dt-center"}]

# After you created `merged_df` and 'is_correct' etc:

# Only for coloring, let's leave colors simple for now
show(merged_df)
# Out:
# <table id="itables_6704260d_1c96_4264_b5aa_89e3d4348869" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>S.No_meta</th>
#       <th>question_id</th>
#       <th>prompt_name_meta</th>
#       <th>subject_meta</th>
#       <th>domain_meta</th>
#       <th>skill_meta</th>
#       <th>subskill_meta</th>
#       <th>difficulty_meta</th>
#       <th>S.No_cluster</th>
#       <th>prompt_name_cluster</th>
#       <th>subject_cluster</th>
#       <th>domain_cluster</th>
#       <th>skill_cluster</th>
#       <th>subskill_cluster</th>
#       <th>difficulty_cluster</th>
#       <th>cluster</th>
#       <th>assigned_domain</th>
#       <th>is_correct</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.3.0 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.2.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_6704260d_1c96_4264_b5aa_89e3d4348869:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[24, "m_4mohcovg", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 24, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [103, "me_0pum04uz", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 103, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [138, "me_7k1m1k4c", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 138, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [267, "me_cpyzj9ob", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 267, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [287, "fb878b65b0", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 287, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [293, "me_8l02jlzg", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 293, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [325, "m_n68e2hq7", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 325, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [326, "m_8id2cgmh", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 326, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [342, "m_o1t6cieb", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 342, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [344, "m_sk65cxu6", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 344, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 0, "ALG", false], [378, "m_mlruzirp", "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 378, "PID-M-ADM-EQE-EMT-EAS", "M", "ADM", "EQE", "EMT", "EAS", 2, "ADM", true], [26, "me_0y4lwaz9", "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 26, "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 2, "ADM", true], [130, "me_hwgiopa8", "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 130, "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 2, "ADM", true], [156, "m_kamjqh9q", "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 156, "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 2, "ADM", true], [179, "04f71627cb", "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 179, "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 2, "ADM", true], [194, "m_uvoettew", "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 194, "PID-M-ADM-EQE-EMT-HAR", "M", "ADM", "EQE", "EMT", "HAR", 2, "ADM", true], [34, "m_yjlgzbv1", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 34, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [72, "m_frt897ry", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 72, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [83, "3b20fffe61", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 83, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [101, "m_mp9jcz72", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 101, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [241, "m_qpc733lh", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 241, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [295, "me_vbquzby2", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 295, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [358, "me_v4rtw6l2", "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 358, "PID-M-ADM-EQE-EMT-MED", "M", "ADM", "EQE", "EMT", "MED", 2, "ADM", true], [9, "me_8r4fr1ej", "PID-M-ADM-EQE-EMT-VHA", "M", "ADM", "EQE", "EMT", "VHA
